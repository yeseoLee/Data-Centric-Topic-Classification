# %%
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
from langchain.prompts.chat import (
    ChatPromptTemplate,
    SystemMessagePromptTemplate,
    HumanMessagePromptTemplate,
)
import time
import torch
import pandas as pd
import random
import re
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline

# %%
# 모델과 토크나이저를 명시적으로 로드
model_name = "LGAI-EXAONE/EXAONE-3.0-7.8B-Instruct"
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
model = AutoModelForCausalLM.from_pretrained(model_name, trust_remote_code=True)

# 파이프라인 생성 및 설정
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    device="cuda"
)
# Out:
# Loading checkpoint shards:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
# 입력 텍스트 설정
input_text = """p-축구M인천 ,qN 35c운드 r&Q{영`
위 문장은 축구 관련 기사 제목을 노이징한거야. 원래 제목을  추론해줘.
"""

# 텍스트 생성 시 세부 옵션 지정
output = pipe(
    input_text,
    max_length=100,          # 생성할 텍스트의 최대 길이
    temperature=0.7,        # 다양성 조절 (0.7은 적절한 온도)
    top_k=50,               # 상위 50개의 후보에서 선택
    top_p=0.9,              # 상위 90% 누적 확률에서 선택
    num_return_sequences=1,  # 반환할 응답의 수
    truncation=True  # 텍스트가 max_length를 넘으면 잘라냄
)

print(output)
# Out:
# [{'generated_text': 'p-축구M인천 ,qN 35c운드 r&Q{영`\n위 문장은 축구 관련 기사 제목을 노이징한거야. 원래 제목을  추론해줘.\n\n문장: "M인천, 35라운드에서 승리를 거두며 상위권 진입을 노리고 있다."\n\n추론된 원래 제목:\n"M인천, 35라운드에서 승리하며 상위권 진입 희망"\n\n설명'}]

# %% [markdown]
# LangChain에서 Hugging Face 모델을 연결하기 위해, 먼저 Transformers 라이브러리로 모델을 로드한 뒤 pipeline 객체를 생성합니다.

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

# Load the tokenizer and model
model_name = "LGAI-EXAONE/EXAONE-3.0-7.8B-Instruct"
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
model = AutoModelForCausalLM.from_pretrained(model_name, trust_remote_code=True)


# GPU 사용 가능 시 모델을 GPU로 이동
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)
# Out:
# Loading checkpoint shards:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
# Load few-shot-example and need_denoise data
few_shot_df = pd.read_csv("../../data/5_base_noise_detected_test_with_predictions.csv")  # ID, text, target columns
need_denoise_df = pd.read_csv("../../data/5_base_noise_detected_train.csv")  # ID, text, target columns with noise

# %%
# Split few_shot_df into 7 dataframes based on target labels (0 to 6)
label_dfs = {label: few_shot_df[few_shot_df['target'] == label] for label in range(7)}

# %%
def add_extended_ascii_noise(text, noise_level=0.5):
    noisy_text = ""
    for char in text:
        if random.random() < noise_level:
            # ASCII와 확장된 범위에서 임의의 문자 선택
            if random.random() < 0.93:
                # ASCII 범위 내 특수 문자, 대소문자, 숫자
                noisy_text += chr(random.randint(33, 126))  
            else:
                # 한자 유니코드 범위 (CJK 범위 일부 예시)
                noisy_text += chr(random.randint(0x4E00, 0x9FFF))  
        else:
            noisy_text += char
    return noisy_text

# %%
# 예시: label 데이터 5개 뽑기 및 노이즈 추가
few_shot_examples = label_dfs[4].sample(5)
sample_list = "예시: \n"
for _, example_row in few_shot_examples.iterrows():
    # 아스키 기반 노이즈 추가
    original_example = example_row['text']
    noisy_example = add_extended_ascii_noise(original_example)
    sample_list += f"입력된 제목: {noisy_example}\n복원된 제목: {original_example}\n\n"

print(sample_list)
# Out:
# 예시:
# 입력된 제목: UrE }텔 垎4f학/술f진I회 대Li6沍j2
# 복원된 제목: 게시판 인텔 국제과학기술경진대회 대표단 발대식
#
# 입력된 제목: &아F 드]"빙 시뮬레V6
# 복원된 제목: 세아트 드라이빙 시뮬레이터
#
# 입력된 제목: 1r∼(u대는1유aX F대…하FF4p4n 9E< 본吔
# 복원된 제목: 10∼20대는 유튜브 세대…하루 4.4회 52분 본다
#
# 입력된 제목: -K. 미7d,객 잡5다
# 복원된 제목: SKT 미래 고객 잡는다
#
# 입력된 제목: '탁J鏊%訛D워P그룹과C분~^부X기@y공동p구泐纚B
# 복원된 제목: 예탁원 CSD워킹그룹과 분산장부 기술 공동연구 협약

# %%
# Function to generate denoised text for each entry in need_denoise_df
def denoise_text_with_few_shot(row, label_dfs):
    target_label = row['target']
    noisy_text = row['text']
    
    # 같은 label 데이터 3개를 뽑아서 few-shot으로 활용
    few_shot_examples = label_dfs[target_label].sample(3)
    sample_list = "예시: \n"
    for _, example_row in few_shot_examples.iterrows():
        # 아스키 기반 노이즈 추가
        original_example = example_row['text']
        noisy_example = add_extended_ascii_noise(original_example)
        sample_list += f"입력된 제목: {noisy_example}\n복원된 제목: {original_example}\n\n"
    
    # Construct few-shot prompt
    prompt = """다음은 아스키코드가 치환되는 방식으로 많은 노이즈가 있는 한국어 뉴스 기사 제목입니다.
    노이즈가 들어가지 않은 한글부분을 참고하여 원래의 정확한 한국어 제목으로 복원해주세요.
    앞뒤에 설명 붙이지 말고, 반드시 복원된 제목만 대답하세요.
    아래의 예시는 동일한 주제의 복원된 뉴스기사 제목입니다.
    예시를 참고하여 예시와 반드시 동일한 주제로 복원하세요.
    입력된 제목보다 짧지 않도록 생성하세요.
    """
    prompt += sample_list
    prompt += f"""입력된 제목: {noisy_text}
    복원된 제목:"""

    # Generate denoised text using the model
    
    # # pad_token이 없으면 eos_token을 pad_token으로 설정
    # if tokenizer.pad_token is None:
    #     tokenizer.pad_token = tokenizer.eos_token
    
    inputs = tokenizer.encode(prompt, return_tensors="pt", max_length=512, truncation=True).to(device) # 기본
    # inputs = tokenizer(prompt, return_tensors="pt", padding=True, truncation=True, max_length=512) # 라마
    # input_ids = inputs["input_ids"].to(device)
    # attention_mask = inputs["attention_mask"].to(device)
    outputs = model.generate(
            inputs, # 라마제외
            # input_ids, # 라마
            max_new_tokens=20,            
            num_return_sequences=1,
            no_repeat_ngram_size=2,
            top_k=50,
            top_p=0.9,
            temperature=0.7,
            do_sample=True,
            # attention_mask=attention_mask,              # Attention mask 추가 (라마)
            # pad_token_id=tokenizer.eos_token_id,        # pad_token_id를 eos_token_id로 설정 (라마)
                             )
    restored_headline = tokenizer.decode(outputs[0], skip_special_tokens=True)

    # "복원된 제목:" 이후의 텍스트 추출
    if "복원된 제목:" in restored_headline:
        restored_headline = restored_headline.split("복원된 제목:")[-1].strip()
    # "답변:" 부분 제거
    restored_headline = re.sub(r"^답변:\s*", "", restored_headline)
    
    # 줄바꿈 이후 내용 자르기, 예외 발생 시 빈 문자열 할당
    try:
        restored_headline = restored_headline.splitlines()[0]
    except IndexError:
        restored_headline = ""

    
    
    print(f"\n{sample_list}")
    print("--------------------------------------------")
    print(f"결과 : {noisy_text} -- {restored_headline}")
    print("--------------------------------------------")

    return restored_headline.strip()

# %%
import time
import os
import pandas as pd

# 기존 파일이 있는지 확인하고 불러오기
save_path = "denoised_results.csv"

if os.path.exists(save_path):
    # 기존 진행 파일 불러오기
    need_denoise_df = pd.read_csv(save_path)
    # 'denoised_text' 열에 NaN 값만 남아있는 인덱스를 찾음
    last_processed_index = need_denoise_df['denoised_text'].last_valid_index() or -1
else:
    # 파일이 없으면 처음부터 시작
    last_processed_index = -1
    need_denoise_df['denoised_text'] = ""

total_rows = len(need_denoise_df)
print(f"Resuming from row {last_processed_index + 1}...")

# 각 행을 순회하며 denoise 함수 적용 및 중간 진행 저장
for index, row in need_denoise_df.iterrows():
    if index <= last_processed_index:
        continue  # 이미 처리한 행은 건너뜀
    
    start_time = time.time()
    
    try:
        # 현재 행에 대한 denoised_text 생성
        denoised_text = denoise_text_with_few_shot(row, label_dfs)
    except Exception as e:
        print(f"Error processing row {index}: {e}")
        denoised_text = ""  # 오류 시 빈 문자열로 대체
    
    # denoised_texts 리스트에 추가
    need_denoise_df.at[index, 'denoised_text'] = denoised_text
    
    end_time = time.time()
    elapsed_time = end_time - start_time
    print(f"Processed {index + 1}/{total_rows} rows - Time taken: {elapsed_time:.2f} seconds.")
    
    # 100행마다 중간 진행 저장
    if (index + 1) % 100 == 0:
        need_denoise_df.to_csv(save_path, index=False)
        print(f"Checkpoint saved at row {index + 1}.")

# 최종 저장
need_denoise_df.to_csv(save_path, index=False)
print("Final denoised results saved.")
# Out:
# Resuming from row 0...
#
# 예시:
# 입력된 제목: 한국MSU윈鰍1t IoT T디dQ*시UB2B LC
# 복원된 제목: 한국MS 윈도10 IoT 에디션 출시…B2B 공략
#
# 입력된 제목: 네咼버 R문~& 검색 내6D안에 y글0櫻U"tY것
# 복원된 제목: 네이버 전문자료 검색 내년 안에 구글 따라잡을 것
#
# 입력된 제목: .글k/세대 "롬7스l 출$_C세Z%`?씨Q단W 0O종O
# 복원된 제목: 구글 3세대 크롬캐스트 출시…신세계아이앤씨 단독 판매종합
#
#
# --------------------------------------------
# 결과 : 정i :파1 미사z KT( 이용기간 2e 단] Q분종U2보 -- 정조대왕 파초선 미사리에서 KT 이용 기간 12분 동안 공개
# --------------------------------------------
# Processed 1/1602 rows - Time taken: 17.81 seconds.
#
# 예시:
# 입력된 제목: 직원莔?c에 j력 행gU}t!*塖1조'Z혁신센UG V유
# 복원된 제목: 직원 채용에 압력 행사한 전 대구창조경제혁신센터장 집유
#
# 입력된 제목: e천2공s유치원C교사 8{D Yy 중 질{(l어
# 복원된 제목: 인천 공립유치원 교사 87% 근무 중 질병 얻어
#
# 입력된 제목: 이통 K/점들6완Gp급제법Ax속 추V 유감E부n용hB
# 복원된 제목: 이통 판매점들 완전자급제법 졸속 추진 유감…부작용 커
#
#
# --------------------------------------------
# 결과 : K찰.국DLwo 로L3한N% 회장 2 T0&}송= -- 한국당 대표 후보들로 구성된 한나라연합회 회장 송 후보
# --------------------------------------------
# Processed 2/1602 rows - Time taken: 17.23 seconds.
#
# 예시:
# 입력된 제목: 靑M시o頑%ENI0烌으로@勂,#Z구라도z좋다
# 복원된 제목: 靑 시선은 벌써 특검으로…후보 누구라도 좋다
#
# 입력된 제목: 北0무~단 9而| 발사1v…軍k;발 yg <刬q화종합
# 복원된 제목: 北 무수단 미사일 발사준비…軍 도발 대비 감시강화종합
#
# 입력된 제목: 평傠정-회HU휴a 장`로r이6n".f@ 정沗
# 복원된 제목: 평양정상회담 휴식 장소로 이동하는 남북 정상
#
#
# --------------------------------------------
# 결과 : m 김정) 자주통일 새,?r열1나가야1보 -- 문재인 대통령 자주 통일 새 시대 열어나가야
# --------------------------------------------
# Processed 3/1602 rows - Time taken: 16.89 seconds.
#
# 예시:
# 입력된 제목: XO평Hi 소?에 아프리IB4'…각국^m상 환yW聏+라
# 복원된 제목: 노벨평화상 소식에 아프리카 환호…각국 정상 환영 잇따라
#
# 입력된 제목: 祻안RWUi%리,+4리 <3Rm에 kP n @무i관
# 복원된 제목: 치안불안 아프리카 말리 새 총리에 시세 전 재무장관
#
# 입력된 제목: 러시아>#리?F `5PMgu사했Xu愩 국방c} 부q
# 복원된 제목: 러시아 시리아서 S500 발사했나…러 국방부는 부인
#
#
# --------------------------------------------
# 결과 : pI美대선I앞두고 R2fr단 발] $비해 감시 강화 -- 미국 대선 앞두고 러시아 사찰 강화...미국 감시에도 불구
# --------------------------------------------
# Processed 4/1602 rows - Time taken: 17.20 seconds.
#
# 예시:
# 입력된 제목: #L`I유튜브UA峧반기213경e 생중fZ콘텐( 독점Q/공
# 복원된 제목: MLB 유튜브에 후반기 13경기 생중계 콘텐츠 독점 제공
#
# 입력된 제목: KL나H|승E 대표(G>Y은8O5K耪꿈x?회.T리라~:어
# 복원된 제목: 베로나 이승우 대표팀 승선은 간절한 꿈…기회 오리라 믿어
#
# 입력된 제목: (>0게墻 7르기스스~P |^ 巺학범p스?로 만든T가J5L
# 복원된 제목: 아시안게임 키르기스스탄전 앞둔 김학범 스스로 만든 가...
#
#
# --------------------------------------------
# 결과 : 프로야구~롯TKIAs광주 경기 y천취소 -- KBO 프로야구 광주 경기 우천 취소
# --------------------------------------------
# Processed 5/1602 rows - Time taken: 17.58 seconds.
#
# 예시:
# 입력된 제목: &중A窛湖분谤 빅뉴i 기대감에5원달러^Sr"하c
# 복원된 제목: 미중 무역분쟁 빅뉴스 기대감에 원달러 환율 하락
#
# 입력된 제목: Ryj상w k'fAT14스5ETF~3종
# 복원된 제목: 증시신상품 국채선물 인버스 ETF 3종
#
# 입력된 제목: i래竈 N국 주Yi幌悦P거래량i추@
# 복원된 제목: 그래픽 전국 주택 매매 거래량 추이
#
#
# --------------------------------------------
# 결과 : oi 매력 R모h츠a열#w3약 >l·주가 고Q/진 -- 로봇 산업 매력도 상승 주가 상승 전망
# --------------------------------------------
# Processed 6/1602 rows - Time taken: 16.99 seconds.
#
# 예시:
# 입력된 제목: n$버a모바E E寶화j 검)$ 위주 개{)每`>실Hs 뺀다종합
# 복원된 제목: 네이버 모바일 첫 화면 검색창 위주 개편…뉴스·실급검 뺀다종합
#
# 입력된 제목: SKT C산 엑스포서Ow양j< Y신기b 시연
# 복원된 제목: SKT 부산 엑스포서 해양안전 통신기술 시연
#
# 입력된 제목: `w화zK플i폼+.n빌蚔侪0J잠금~면앱UUF이드 인[
# 복원된 제목: 잠금화면 플랫폼 버즈빌 인도 잠금화면앱 슬라이드 인수
#
#
# --------------------------------------------
# 결과 : 아이`XSI수리0* b대`…맥3 디dF레< 41/' -- 인공지능 스피커 수리 서비스 확대...마이크로소프트 디브러시 3단계 서비스 출시
# --------------------------------------------
# Processed 7/1602 rows - Time taken: 17.42 seconds.
#
# 예시:
# 입력된 제목: 2W하는~9해찬 대표와 파Jd负페M 주한'프랑y대사
# 복원된 제목: 환담하는 이해찬 대표와 파비앙 페논 주한 프랑스대사
#
# 입력된 제목: 8안F 18일J김창보 }앙선관위원 후3자偀FH청8회 -眤
# 복원된 제목: 행안위 18일 김창보 중앙선관위원 후보자 인사청문회 개최
#
# 입력된 제목: 대북특6단2오) l시 b양 [&…10시부} jY y2보
# 복원된 제목: 대북특사단 오전 9시 평양 안착…10시부터 회담 중2보
#
#
# --------------------------------------------
# 결과 : 문/인 당2 4nS 민관2동7사위 /"X보 철거tt -- 문재인 대통령, 민관동 7층 사택 철거 지시
# --------------------------------------------
# Processed 8/1602 rows - Time taken: 19.25 seconds.
#
# 예시:
# 입력된 제목: 북\이는h飣악e籡G}l
# 복원된 제목: 북적이는 송악산 선착장
#
# 입력된 제목: V-부=피해% 그림9洹생님이 전하는az야기
# 복원된 제목: 위안부 피해자 그림 선생님이 전하는 이야기
#
# 입력된 제목: L縚 j일W刿국 0`+7비…4풍 1향권 5주·S해안 3e
# 복원된 제목: 날씨 6일 전국 흐리고 비…태풍 영향권 제주·남해안 강풍
#
#
# --------------------------------------------
# 결과 : 개R전 연w정연H 작가 -- 개관 전 연지연 작가 전시회
# --------------------------------------------
# Processed 9/1602 rows - Time taken: 15.98 seconds.
#
# 예시:
# 입력된 제목: 프로야k vX\.-일부터q&본C고@ o무XM훈련
# 복원된 제목: 프로야구 LG 29일부터 일본 고치 마무리 훈련
#
# 입력된 제목: 힐러Z W우스캐v0이}圎경L서^L더鵛 꺾고 *P2보
# 복원된 제목: 힐러리 사우스캐롤라이나 경선서 샌더스 꺾고 승리2보
#
# 입력된 제목: 새0즌0준I 류현진".7徦橻S울?&팬Z팅
# 복원된 제목: 새시즌 준비 류현진 27일 서울서 팬미팅
#
#
# --------------------------------------------
# 결과 : KIA I수단·팬nI께하는:호kQ4M족 한마5 S최 -- 기아 팀·판마팬 모임:호주 팀과 교류 행사 진행
# --------------------------------------------
# Processed 10/1602 rows - Time taken: 16.85 seconds.
#
# 예시:
# 입력된 제목: j도로 출발하기 QK기i鍤영dig )도아카데j 대학3
# 복원된 제목: 독도로 출발하기 전 기념촬영 하는 독도아카데미 대학생
#
# 입력된 제목: 게d8 관$공qI대Y생 F?여행 슬로건cVW전 개최
# 복원된 제목: 게시판 관광공사 대학생 안전여행 슬로건 공모전 개최
#
# 입력된 제목: V轡bjQ$ 방u1-장##영u송_h ,념식 참석
# 복원된 제목: 동정 이효성 방통위원장 민영방송의날 기념식 참석
#
#
# --------------------------------------------
# 결과 : 현N차sJ <e 임원6늘려…~세z 리g (보j 육y -- 현대자동차 임원 수 늘리고 비정규직 노동자 정규직 전환 추진
# --------------------------------------------
# Processed 11/1602 rows - Time taken: 16.94 seconds.
#
# 예시:
# 입력된 제목: 사v버7fj대비 ET=%x賙n$42H 긴9w보F+검Uw
# 복원된 제목: 사이버테러 대비 IT기반시설 142곳 긴급 보안점검종합
#
# 입력된 제목: )+L·'U}\ S&艤구6용J:[Ob* n집
# 복원된 제목: 미래부·창의재단 SW교구활용 교사연구회 모집
#
# 입력된 제목: 게시판 K` 대)생擬勣단L)춤형 7회공헌#활동
# 복원된 제목: 게시판 HF 대학생봉사단 맞춤형 사회공헌 활동
#
#
# --------------------------------------------
# 결과 : -선 폭:n@ 현장N조Z -- 선거운동 현장조사 및 조례활동 보고
# --------------------------------------------
# Processed 12/1602 rows - Time taken: 18.14 seconds.
#
# 예시:
# 입력된 제목: 충주 호h택r지&Yv:개漋Jwg 繚달 말 동T謃偌
# 복원된 제목: 충주 호암택지지구서 4개 아파트 이달 말 동시분양
#
# 입력된 제목: 금%협회 1.O 황영&羝증시4伳5M회복이r최6 과D
# 복원된 제목: 금투협회 떠나는 황영기 증시 신뢰 회복이 최대 과제
#
# 입력된 제목: hL피8Wg발 p.~i또_급抒…236森대로 !V
# 복원된 제목: 코스피 미국발 악재에 또 급락…2360대로 털썩
#
#
# --------------------------------------------
# 결과 : STJ레콤 J분기 영D익t4천105t…2>1％ 증가 -- SK텔레컴 분기 영업이익 7천억1백50억...전년
# --------------------------------------------
# Processed 13/1602 rows - Time taken: 18.74 seconds.
#
# 예시:
# 입력된 제목: &국fPq진흥萂鄔랜섬웨어tfu 암6iq {7 착B
# 복원된 제목: 한국인터넷진흥원 랜섬웨어 예방 암호기술 연구 착수
#
# 입력된 제목: 게D판W@鈑m y천공*FhU서비Vwj命*)CN만족도 1/
# 복원된 제목: 게시판 LGU 인천공항 로밍서비스 7회 연속 만족도 1위
#
# 입력된 제목: s래=oVR~A> 펀瓮 운m사n+케이z브S처스r선정
# 복원된 제목: 미래부 VR·AR 펀드 운용사에 케이큐브벤처스 선정
#
#
# --------------------------------------------
# 결과 : 생r인증②_D안*a제bK 유@되면 대J _가끝 -- 생체 인증 2단계 도입으로 개인정보 보호 강화 방안 검토
# --------------------------------------------
# Processed 14/1602 rows - Time taken: 18.89 seconds.
#
# 예시:
# 입력된 제목: 승리!도鹸*Uh던 9P원 V1 엔a璬)끈 ' 같다
# 복원된 제목: 승리에도 침통했던 박기원 감독 엔진을 끈 것 같다
#
# 입력된 제목: 울산현B고竦아디다스 ;리그 고R>R축구湋a 4년 연$e우b
# 복원된 제목: 울산현대고 아디다스 K리그 고등부 축구리그 4년 연속 우승
#
# 입력된 제목: l{ 전g훈련 )치고 I'x귀!9麜프~&)P는 [재영·'jF
# 복원된 제목: 넥센 전지훈련 마치고 6일 귀국…캠프 MVP는 신재영·김지수
#
#
# --------------------------------------------
# 결과 : GD n{n.강d}감독 2로축구연맹WS7(0/회부 -- FC 서울 감독 강희석, 7월 리그컵 대회 3연패 도전
# --------------------------------------------
# Processed 15/1602 rows - Time taken: 19.72 seconds.
#
# 예시:
# 입력된 제목: 프로f구F`삼挑^ 燤h퍼BZ鍈OO y상…]체할~듯
# 복원된 제목: 프로농구 인삼공사 컬페퍼 햄스트링 부상…교체할 듯
#
# 입력된 제목: 6E스 켈p 너마저…nK 선발진;\쇄 I괴
# 복원된 제목: 에이스 켈리 너마저…SK 선발진 연쇄 붕괴
#
# 입력된 제목: 넥센J10kAG綅?고x-Y 귀국…k프 胙VP는 신재]·T2수
# 복원된 제목: 넥센 전지훈련 마치고 6일 귀국…캠프 MVP는 신재영·김지수
#
#
# --------------------------------------------
# 결과 : p-축구M인천 ,qN 35c운드 r&Q{영` -- 축구 인천, 5경기 연속 무승...감독 교체 필요
# --------------------------------------------
# Processed 16/1602 rows - Time taken: 19.60 seconds.
#
# 예시:
# 입력된 제목: l*钿레G I$' 네트워크 ]N哒맞춤sDV스
# 복원된 제목: SK텔레콤 IoT 네트워크 기반 맞춤 서비스
#
# 입력된 제목: 이스트.+리9 ?국인ej진흥瓕에 6P>}$`H솔N=p}급
# 복원된 제목: 이스트시큐리티 한국인터넷진흥원에 APT 대응 솔루션 공급
#
# 입력된 제목: LG유플러八 U+G도EN서비스`r대
# 복원된 제목: LG유플러스 U파손도움 서비스 확대
#
#
# --------------------------------------------
# 결과 : 해외로밍 m금폭탄 n동차단 더 빨$진다 -- 해외로메이지출 폭탄 문자 차단 속도 빨라진다 2023년
# --------------------------------------------
# Processed 17/1602 rows - Time taken: 18.26 seconds.
#
# 예시:
# 입력된 제목: 경m^E재 영VnT송인 c~|민O룡 88v骂
# 복원된 제목: 경찰 소재 영화ㆍ방송인 맞는 민갑룡 경찰청장
#
# 입력된 제목: 2A2m <반기 해외g업 화>ZdB주간g행사
# 복원된 제목: 2020 하반기 해외취업 화상면접 주간 행사
#
# 입력된 제목: 과기단체 연구윤8/훼손r 鋜B심A윤리 O범 阷련하a다
# 복원된 제목: 과기단체 연구윤리 훼손에 경각심…윤리 규범 마련하겠다
#
#
# --------------------------------------------
# 결과 : 세계K인무역협회 올S#$'2 무역인 1천b55w 배출한( -- 세계경제인협회 올해 3천명 무역 인력 배출
# --------------------------------------------
# Processed 18/1602 rows - Time taken: 19.20 seconds.
#
# 예시:
# 입력된 제목: 대7o공)>S∼W<If나筲노K 첫 취항
# 복원된 제목: 대한항공 인천∼바르셀로나 노선 첫 취항
#
# 입력된 제목: U .钗번|LA자…여자U_ 鰰표lA疆n하는 H테랑p c
# 복원된 제목: 일 한 번 내보자…여자축구 대표팀 지탱하는 베테랑의 힘
#
# 입력된 제목: p揎A에서@,孨: #구화 들고 블록N 5{…D\으니a焃&
# 복원된 제목: NBA에서 벗겨진 농구화 들고 블록슛 시도…막았으니 됐다
#
#
# --------------------------------------------
# 결과 : 박항C 매직c베트남i축구_표팀K.?^# 쏟;*:d -- 베트남 축구 대표 팀, 박 감독 매직으로 승리
# --------------------------------------------
# Processed 19/1602 rows - Time taken: 20.07 seconds.
#
# 예시:
# 입력된 제목: .주화rt 보)f2Z 국)배g勹안dgr헌재F$반대 耙결
# 복원된 제목: 민주화운동 보상받으면 국가배상 안 돼…헌재와 반대 판결
#
# 입력된 제목: 국민 (0명 중 8XT(41기(로(일자리C줄어들 것
# 복원된 제목: 국민 10명 중 8명 혁신 기술로 일자리 줄어들 것
#
# 입력된 제목: %탁yUN9X물관 서mRf^浻wZ 인y
# 복원된 제목: 예탁원 증권박물관 서울학생배움터로 인증
#
#
# --------------------------------------------
# 결과 : 학~ 석면 S거 규정k지키5 -- 학교 석면 관리 규정 지키면 5년마다 검사
# --------------------------------------------
# Processed 20/1602 rows - Time taken: 18.86 seconds.
#
# 예시:
# 입력된 제목: ~지는CCjP 0셋F보i결訵…zj4Sw0I트w도"패치해V종합
# 복원된 제목: 커지는 CPU 칩셋 보안결함…PC 외 스마트폰도 패치해야종합
#
# 입력된 제목: PT*5G?xW?~%감기d.9w 확대 적S
# 복원된 제목: KT 5G 배터리 절감기술 전국 확대 적용
#
# 입력된 제목: 골프a*u크A골프R프랜차이즈 전w 시"%운YHy j집
# 복원된 제목: 골프존 스크린골프 프랜차이즈 전환 시범 운영매장 모집
#
#
# --------------------------------------------
# 결과 : dcST C, 생산 인공광Fy에d"기보다BS에*!6활ht"y@적 -- 반도체 생산 인공지능 기술 개발에 더 활발하게 적용돼
# --------------------------------------------
# Processed 21/1602 rows - Time taken: 19.61 seconds.
#
# 예시:
# 입력된 제목: 되살D난 트라우n 롯G 연(에 *고vS정dg*&
# 복원된 제목: 되살아난 트라우마 롯데 연패에 울고 판정에 울고
#
# 입력된 제목: Bc 우g6+ 코치로N"리Q 복|8;8-좋}r
# 복원된 제목: 마틴 우리카드 코치로 V리그 복귀…한국 좋아요
#
# 입력된 제목: D}申 플侱1 강茖호 h격UT유지하기가 힘드네요
# 복원된 제목: 지겨운 플래툰 강정호 타격감 유지하기가 힘드네요
#
#
# --------------------------------------------
# 결과 : 다저스 _버츠 감독J류현4 담당 포수!최! 환^ 만들P... -- 다저스 버츠 코치 류현 4번 타자 담당! 최환 코치가 만들어냈
# --------------------------------------------
# Processed 22/1602 rows - Time taken: 19.23 seconds.
#
# 예시:
# 입력된 제목: 장애Hk정鞊|발1하'2안耫`
# 복원된 제목: 장애인 정책 발표하는 안철수
#
# 입력된 제목: 김현미 賜栢세상한제7r규 N약 rx\i려y f R아X신중g
# 복원된 제목: 김현미 전월세상한제 신규 계약 적용 고려할 점 많아 신중론
#
# 입력된 제목: 文v통0O铒목선*X'못&;j국Kg 9대로 못*려Z철OF})(n
# 복원된 제목: 文대통령 北목선 경계못하고 국민께 제대로 못알려…철저 점검종합
#
#
# --------------------------------------------
# 결과 : W;E& F일 연k상t의장 G견u창조경제 논의 -- 경제협력개발기구(OECD) 일연상 의장 창조경제 관련 논의 진행
# --------------------------------------------
# Processed 23/1602 rows - Time taken: 20.23 seconds.
#
# 예시:
# 입력된 제목: 蓀`닷槠 재- 6Me자택6_.가격#鹯qyO7승
# 복원된 제목: 재벌닷컴 재벌 총수 자택 공시가격 34% 상승
#
# 입력된 제목: R9' 蕒{F구매 }{p…m데닷컴 e해 ]y雎매출*2O%h
# 복원된 제목: 온라인 명품 구매 늘었다…롯데닷컴 올해 명품 매출 25%↑
#
# 입력된 제목: .성2 ^선&FU재U업* fx ;원g경4력hP고 돕겠다
# 복원된 제목: 은성수 조선 기자재 업체 적극 지원…경쟁력 제고 돕겠다
#
#
# --------------------------------------------
# 결과 : 산업생산jQ8째 L고 제조1가동률은-금융위jS수yk합2보 -- 제조업 가동률 하락, 금융위 "적극 지원"
# --------------------------------------------
# Processed 24/1602 rows - Time taken: 20.58 seconds.
#
# 예시:
# 입력된 제목: 4이[0 餪는z!;|艙스t+ 8i에''영…L시6사 _!~
# 복원된 제목: 페이스북 읽는 시간 뉴스피드 랭킹에 반영…낚시기사 불이익
#
# 입력된 제목: 안산.mu·j전·G여에서 8후 Me건虸물9리뉴l 사업
# 복원된 제목: 안산·대구·대전·부여에서 노후 공공건축물 리뉴얼 사업
#
# 입력된 제목: T주S櫛L위懥장 코로나+9 n복 비A 재S이x적Q "담扜A
# 복원된 제목: 민주노총 위원장 코로나19 극복 비용 재벌이 적극 부담해야
#
#
# --------------------------------------------
# 결과 : x' 유^ 의H%eprM못gz고r사표…특별1LX제 흔들 -- 유시민 대표, 특별위원회 구성 제안...사회적 약자 지원 강화
# --------------------------------------------
# Processed 25/1602 rows - Time taken: 22.13 seconds.
#
# 예시:
# 입력된 제목: p&J입竮한 남북 =v단 그 사연h
# 복원된 제목: 지각 입장한 남북 선수단 그 사연은
#
# 입력된 제목: 콘tPWE 4독 p테琧`S로蠙_ 출]-부 D&이 Ay할<;
# 복원된 제목: 콘테 첼시 감독 캉테 AS로마전 출전여부 본인이 결정할 것
#
# 입력된 제목: 통일賃구 `북단睞m蕳R조Q균0殥z교류u계o A어+ 것Lx.
# 복원된 제목: 통일농구 방북단 귀환…조명균 체육교류 계속 이어질 것...
#
#
# --------------------------------------------
# 결과 : 5자농R 4R은행f삼[m명 꺾$N$직@P { -- 축구 200경기 출전한 선수가 은행원 꺾었다
# --------------------------------------------
# Processed 26/1602 rows - Time taken: 20.75 seconds.
#
# 예시:
# 입력된 제목: 외2부 송y순 cNa 관Y 驾疁tS5鄩없어
# 복원된 제목: 외교부 송민순 회고록 관련 언급할 사안없어
#
# 입력된 제목: tt {동당 제P차w涹회處b월 T9i개;lm
# 복원된 제목: 북한 노동당 제7차 대회 5월 6일 개최2보
#
# 입력된 제목: s순삼 홍Xy\j나라 m급LX때_바로 n아줄L후/
# 복원된 제목: 이순삼 홍준표는 나라 위급할 때 바로 잡아줄 후보
#
#
# --------------------------------------------
# 결과 : 김종ll리먼 ^라더스 사태처럼 6Mq 충격@지속"KIN을 것 -- 김중권 리더먼 사태와 같은 충격 지속, 큰 변화 예상
# --------------------------------------------
# Processed 27/1602 rows - Time taken: 19.99 seconds.
#
# 예시:
# 입력된 제목: Gk沭L임 키르기a스1전l앞蠵g김학9*스~로 만든凞가...
# 복원된 제목: 아시안게임 키르기스스탄전 앞둔 김학범 스스로 만든 가...
#
# 입력된 제목: Rx제 <` 1;3g#m진 H저의 투혼…믿"o힘든 遖}.7
# 복원된 제목: 진통제 맞고 103구 던진 셔저의 투혼…믿기 힘든 투...
#
# 입력된 제목: 아시y게v B鳚 B6 晟朌 mrz$/출Z 시리아의詪`;..
# 복원된 제목: 아시안게임 내전 아픔 속에 16강 진출한 시리아의 위...
#
#
# --------------------------------------------
# 결과 : Vq)Z!\자o구 김정Re트로1$보니C.도l모르".Qk이 -- 베트남과 러시아전을 앞둔 김정혁 감독 전략 보니...팀... 76
# --------------------------------------------
# Processed 28/1602 rows - Time taken: 23.44 seconds.
#
# 예시:
# 입력된 제목: 차의과학\-현~그J卼드X현;백화점과 사회S헌협;O嬐결
# 복원된 제목: 차의과학대 현대그린푸드·현대백화점과 사회공헌협약 체결
#
# 입력된 제목: 게시! 한5 알0쉬J_경Ot야. b&C UF7 0상d 선a
# 복원된 제목: 게시판 한은 알기쉬운 경제이야기 UCC 공모전 수상작 선정
#
# 입력된 제목: 시XH 饬3W7기 일pv 1@만F,>P
# 복원된 제목: 시흥시 민선 7기 일자리 10만개 창출
#
#
# --------------------------------------------
# 결과 : 인국공I{태NL년D의 bT,무jlv공u{고?진보인가 -- 인천국제공항공사 2021년도 비정규직의 정규직 전환 논란
# --------------------------------------------
# Processed 29/1602 rows - Time taken: 20.66 seconds.
#
# 예시:
# 입력된 제목: 홍콩 갑부 리카: 올^o=계4제>복잡할 臜e嫏두 조XJ야
# 복원된 제목: 홍콩 갑부 리카싱 올해 세계경제 복잡할 것…모두 조심해야
#
# 입력된 제목: 이\*엘팔레~타인 ?V偊구q晶n+`돌 a< '!
# 복원된 제목: 이스라엘팔레스타인 가자지구 무력 충돌 중지 합의
#
# 입력된 제목: 栿i8y4`囇ssN집2 세N 은행들&상대 V!억U탈취종합
# 복원된 제목: 북한 사이버 공격 집단 세계 은행들 상대 1천억 탈취종합
#
#
# --------------------------------------------
# 결과 : 美MBA[여성 비율x계속 x가4주$E19a대 U입생 중Ym,% -- 미국 MBA 여성 비율 계속 증가 50% 돌파 예상
# --------------------------------------------
# Processed 30/1602 rows - Time taken: 21.02 seconds.
#
# 예시:
# 입력된 제목: }노트c 중국xf2V일 출시…모P일1t A' L대
# 복원된 제목: 갤노트8 중국서 29일 출시…모바일결제 제휴 확대
#
# 입력된 제목: ?MZ}Vp·AR,k焔n9D사에 +UQh-e/ 선4
# 복원된 제목: 미래부 VR·AR 펀드 운용사에 케이큐브벤처스 선정
#
# 입력된 제목: <시^|KT 정보M안 기0 4곳과 MO^
# 복원된 제목: 게시판 KT 정보보안 기업 4곳과 MOU
#
#
# --------------------------------------------
# 결과 : 위클>&스PS)[플코리아7f] 한국서e얼마나 벌!을' -- Weekly 금융코리아 한국 외환시장 얼마나 벌었나 분석
# --------------------------------------------
# Processed 31/1602 rows - Time taken: 19.64 seconds.
#
# 예시:
# 입력된 제목: 6구>< 평균 hZ세#실버9대^도T미k10명 mJ
# 복원된 제목: 농구장에 평균 65세 실버세대 도우미 10명 떴다
#
# 입력된 제목: 경fAR등< 1>만명>ht세정제爼w H생 pT 제공 추=
# 복원된 제목: 경남 초등생 19만명에게 세정제 등 위생 키트 제공 추진
#
# 입력된 제목: 재|법M!mca49]대彮대표憤N이강S 현 교통방' 대표
# 복원된 제목: 재단법인화 tbs 초대 대표에 이강택 현 교통방송 대표
#
#
# --------------------------------------------
# 결과 : 코로나 r대^등교)모습 -- 코로나1차 백신 접종 후 등교 모습
# --------------------------------------------
# Processed 32/1602 rows - Time taken: 19.68 seconds.
#
# 예시:
# 입력된 제목: $祝폰 鑲S감Y挰진PxBJ헬로a사k자烲S와*:찰-<종UR诟
# 복원된 제목: 알뜰폰 위기감 커진다…CJ헬로 사업자협회와 마찰탈퇴종합2보
#
# 입력된 제목: 5금ni 플랫g 3즈o .도_잠금화면B}m라_'夼인수
# 복원된 제목: 잠금화면 플랫폼 버즈빌 인도 잠금화면앱 슬라이드 인수
#
# 입력된 제목: e5T기가r` 내y#W幗T= 8융9^R도 척척F합
# 복원된 제목: KT 기가지니 내일부터 AI 금융서비스도 척척종합
#
#
# --------------------------------------------
# 결과 : 찍W ,fK는 즐거m T졌다…5개 카메: LG V40 z큐 -- 카메라 성능 향상된 LG G7 ThinQ 공개...V450 모델로 추정
# --------------------------------------------
# Processed 33/1602 rows - Time taken: 21.29 seconds.
#
# 예시:
# 입력된 제목: Jg w_$AV 19·S징i담아내는Jc 9!
# 복원된 제목: 인디 게임 개발 개성·특징 담아내는 게 매력
#
# 입력된 제목: 연(부5Fpg시간 lV 데3娾 로9\V능
# 복원된 제목: 연말부터 12시간 단위 데이터 로밍 가능
#
# 입력된 제목: !0∼2ZA는 -튜t 세Io8\ F.4회匓]2분-?다
# 복원된 제목: 10∼20대는 유튜브 세대…하루 4.4회 52분 본다
#
#
# --------------------------------------------
# 결과 : 스마트폰'b실 막는 스l트 트%커 -- 스마트폰 사용 제한하는 소프트웨어 기술
# --------------------------------------------
# Processed 34/1602 rows - Time taken: 18.69 seconds.
#
# 예시:
# 입력된 제목: B8김재수 i임裋Y頴2F출-/옹졸한m정"보uo:공세종합
# 복원된 제목: 與 김재수 해임건의안 제출에 옹졸한 정치보복성 공세종합
#
# 입력된 제목: 반'로 쪼개진vN른미1$罴번A~결9H%표차 아슬r!한sX인P합2K
# 복원된 제목: 반으로 쪼개진 바른미래…두번 표결에 1표차 아슬아슬한 추인종합2보
#
# 입력된 제목: 영상 u출q< 퇴장까f…나경원fY내대표 z란\:I%\
# 복원된 제목: 영상 선출부터 퇴장까지…나경원 원내대표 파란만장 1년
#
#
# --------------------------------------------
# 결과 : 문대통령 김정*m트/프7 YTD 조속히H끝내고 A다고!,p2합 -- 文 대통령 김정은과 조속한 비핵화 끝내고 함께 가자
# --------------------------------------------
# Processed 35/1602 rows - Time taken: 23.81 seconds.
#
# 예시:
# 입력된 제목: 클린턴재단 "폭鰂인ph힐러烬DAhV<럼프 지y율 3%*j 좁[#
# 복원된 제목: 클린턴재단 후폭풍인가…힐러리 vs 트럼프 지지율 3%p로 좁혀져
#
# 입력된 제목: X=먼 진apq시*#~교+)#!참Se6F4 기]i야
# 복원된 제목: 톈안먼 진압 당시 中장교 공개 참회…6·4 기억해야
#
# 입력된 제목: [x수AJk외蓵Z유!서 5럼프마]로 Z+<t판 제안종W
# 복원된 제목: 베네수엘라 외무 유엔서 트럼프마두로 직접 담판 제안종합
#
#
# --------------------------------------------
# 결과 : 한#M2 !는 유`8 치료제 오B솔 美 임{ 3a 본격화 -- 한국 mRNA 백신 치료제 개발 본격 착수
# --------------------------------------------
# Processed 36/1602 rows - Time taken: 21.18 seconds.
#
# 예시:
# 입력된 제목: m주O顊bT망치U bv`步트를Rb계z라
# 복원된 제목: 민주주의를 망치는 포퓰리스트를 경계하라
#
# 입력된 제목: $A[리醆s]wt eDu국제,Hx산v.M…l랍?= 긴급%의종합
# 복원된 제목: 유엔 리비아 내전 악화·국제적 확산 우려…아랍연맹 긴급회의종합
#
# 입력된 제목: 이> yaI/O 개발은it纎m대상>3鬏 재확'
# 복원된 제목: 이란 탄도미사일 개발은 협상 대상 아냐 재확인
#
#
# --------------------------------------------
# 결과 : 아사w 트K프 외교S험k없다고…i5오바I도]KR<8였- -- 미국, 북한과의 외교 협상 없다고 선언...강력한 제재 지속
# --------------------------------------------
# Processed 37/1602 rows - Time taken: 19.17 seconds.
#
# 예시:
# 입력된 제목: 縤주K사Pb외?례j^부rj 공정$
# 복원된 제목: 지주회사 해외사례 공부하는 공정위
#
# 입력된 제목: 2보矣코&피 {승`출발…詉인j매\B 장중 194#선 i복
# 복원된 제목: 2보 코스피 상승 출발…개인 매수에 장중 1940선 회복
#
# 입력된 제목: 보OwU$서.자7&보험>杴UHf바로=가입e4
# 복원된 제목: 보험다모아서 자동차보험 비교후 바로 가입한다
#
#
# --------------------------------------------
# 결과 : CT|2fSSt0 877vA자 10만명 돌, -- 코로나1차 접종 후 7일만에 90%가 3차 백신 맞았
# --------------------------------------------
# Processed 38/1602 rows - Time taken: 19.33 seconds.
#
# 예시:
# 입력된 제목: nQ피(d楟발HmQ에*또 급漢J23+0대e.#썩
# 복원된 제목: 코스피 미국발 악재에 또 급락…2360대로 털썩
#
# 입력된 제목: k娂ec피 전 대표이사`배= !의로 戯r속7기t
# 복원된 제목: 케이에스피 전 대표이사 배임 혐의로 불구속 기소
#
# 입력된 제목: 우8\B酃翀UWQN뱅蝂S서 Jm·공)K/보도 제痸
# 복원된 제목: 우리은행 우리WON뱅킹에서 경매·공매 정보도 제공
#
#
# --------------------------------------------
# 결과 : 유라1아3경w연합r?회q상품/|M3교환 합의 -- 유럽연합 WTO 상품협상 교환각서 서명
# --------------------------------------------
# Processed 39/1602 rows - Time taken: 20.62 seconds.
#
# 예시:
# 입력된 제목: 8미庍饵野F무b기x珂위조H脮澇]-권mZ녀:전락한C정P검찰
# 복원된 제목: 추미애 野 무더기 허위조작 기소…권력시녀 전락한 정치검찰
#
# 입력된 제목: 은D수!후보\b위B麬고 @壙 ,면iZ말(위기3o온=
# 복원된 제목: 은성수 후보자 위기라고 하다 보면 정말 위기가 온다
#
# 입력된 제목: 문楸대통령q국@蝨L觜u74%$지mk보다誰z%藇j葂승갤c@합
# 복원된 제목: 문 대통령 국정지지도 74%…지난주보다 3%P 상승갤럽종합
#
#
# --------------------------------------------
# 결과 : 3부 리수cW^MT北d국제사회<-임M일원!V는데 기4JR9 -- 리수용 북한 대외경제상 국제사회에 임한다...기발한 경제 행보
# --------------------------------------------
# Processed 40/1602 rows - Time taken: 24.45 seconds.
#
# 예시:
# 입력된 제목: 튀/지서Y아랍연맹G-상회의…mpa`골란고!4선r 비판
# 복원된 제목: 튀니지서 아랍연맹 정상회의…트럼프 골란고원 선언 비판
#
# 입력된 제목: 트_프 배i 코d 9- 증언 R기Mu족都s협박,아
# 복원된 제목: 트럼프 배신 코언 의회 증언 연기…가족들 협박받아
#
# 입력된 제목: 트럼w 폭스<b埁앵커7k충DFo,4매!L1?점만I에赜1-4도
# 복원된 제목: 트럼프 폭스뉴스 앵커들 충성도 점수매겨…10점만점에 12점도
#
#
# --------------------------------------------
# 결과 : x콩-P면금[T 나%\…g트=물J1h나고 지>철 %기고 -- 한국의 원자력 발전소 안전성 점검...정부 보고서에 대한 기술적 평가
# --------------------------------------------
# Processed 41/1602 rows - Time taken: 22.28 seconds.
#
# 예시:
# 입력된 제목: 새p椹A갈GW폭발C #/ 전Y위77qS]_p떤!기H
# 복원된 제목: 새누리 갈등 폭발한 상임 전국위·전국위는 어떤 기구
#
# 입력된 제목: 谾 서방에 =두V 연f7먼6h제儖崹K~외교 Fe
# 복원된 제목: 北 서방에 백두산 연구 먼저 제의…과학외교 활발
#
# 입력된 제목: 황}q6각 sG)4상>#8嚣6철저히>강구해u
# 복원된 제목: 황총리 각 부처 비상대비태세 철저히 강구해야
#
#
# --------------------------------------------
# 결과 : T선 D1v 울`B경i활성화;고용안S %&소7?합 -- 트럼프 대통령 일자리 창출 위해 고용안 활성화 강조
# --------------------------------------------
# Processed 42/1602 rows - Time taken: 19.53 seconds.
#
# 예시:
# 입력된 제목: 프]s구@현zAz스EN석'9< 蓛f현wI {Q 감독
# 복원된 제목: 프로농구 현대모비스 수석코치에 조동현 전 kt 감독
#
# 입력된 제목: 프籇D구3fsH신H 2시 -堍…O로( 팀V문화uZ'
# 복원된 제목: 프로야구 SK 신인 상시 교육…새로운 팀 문화 기대
#
# 입력된 제목: 'W농J 신呎은Bv팀W%소a득점m기록a3C점 불명예
# 복원된 제목: 여자농구 신한은행 팀 최소 득점 기록 34점 불명예
#
#
# --------------------------------------------
# 결과 : 월드9U천재 사령탑 S시코 !'O오 감독 한국전R... -- 월드컵 천재 감독 손흥민, 한국 대표팀 감독 취임
# --------------------------------------------
# Processed 43/1602 rows - Time taken: 20.49 seconds.
#
# 예시:
# 입력된 제목: 우g금융碃J&J부m층棄10[Zy2명 노損!zs부y하*_ _W
# 복원된 제목: 우리금융硏 대중부유층 10명중 4명 노후준비 부족하다고 생각
#
# 입력된 제목: 8.E- 尦`Nh_상장O도uJ가3K9%나e상승
# 복원된 제목: 적자전환 실적최악 상장사도 주가는 9%나 상승
#
# 입력된 제목: Hew5부동q1wUhH輲사y*~입
# 복원된 제목: HDC 부동산114 자회사로 편입
#
#
# --------------------------------------------
# 결과 : 특O:H6호에k' Gc모&h금조달에 52P 신고가 -- 특수목적회사 6호기 건설 자금 조달 7200억원 사상최고가 계약
# --------------------------------------------
# Processed 44/1602 rows - Time taken: 20.34 seconds.
#
# 예시:
# 입력된 제목: 회견`s들어서X `준표j지f
# 복원된 제목: 회견장 들어서는 홍준표 지사
#
# 입력된 제목: 靑>추8%v(郁'동净제안에 7&Y榥바 없湔
# 복원된 제목: 靑 추미애 긴급회동 제안에 정해진 바 없다
#
# 입력된 제목: 1宥I통涛f6g掾6|부a+방Z蕻)사g투C
# 복원된 제목: 문 대통령·여야 지도부 지방선거 사전투표
#
#
# --------------------------------------------
# 결과 : 北조국통!민주X#전선 결성 <0돌 중;보고회 열x -- 북한 조국통일 전선 결성 보고대회 열려
# --------------------------------------------
# Processed 45/1602 rows - Time taken: 18.25 seconds.
#
# 예시:
# 입력된 제목: ^sc신e=대K~#07T K마블 첫zIXu보너8
# 복원된 제목: 상장·신작 대박 겹경사에 넷마블 첫 깜짝 보너스
#
# 입력된 제목: 두o9캣 맥/ 컨트롤 e=ae (!제蛨 v드y수상
# 복원된 제목: 두산밥캣 맥스 컨트롤 2019 혁신제품 골드 수상
#
# 입력된 제목: SFB하7u행w호국]훈v체8지W을~위한?/부y1攐蝫
# 복원된 제목: KEB하나은행 호국보훈단체 지원을 위한 기부금 전달
#
#
# --------------------------------------------
# 결과 : aGma일!리"c $산 _R…법정=l 내 처리>W요 -- 매일경제 서울 아파트 분양권 불법 거래 법정에 내소
# --------------------------------------------
# Processed 46/1602 rows - Time taken: 18.53 seconds.
#
# 예시:
# 입력된 제목: K국문화재재단MM2~ J2 N인j<성진 y모鴪|연
# 복원된 제목: 한국문화재재단 12일 장구 명인 이성진 추모 공연
#
# 입력된 제목: 경북 4개 [·군 葺=특>C해3}U부q 비 4쳐
# 복원된 제목: 경북 4개 시·군 호우특보 해제…대부분 비 그쳐
#
# 입력된 제목: -b청NU말하X=더 나은 %상H_화록jv∼5권Y[3
# 복원된 제목: 백낙청이 말하는 더 나은 세상…회화록 6∼7권 출간
#
#
# --------------------------------------------
# 결과 : 본t카 애스턴마틴 Sp라 국내 4P…500대g 생산 -- 본성자동차 애스톤마린 스포츠 모델 국내 생산...총 530대중 36
# --------------------------------------------
# Processed 47/1602 rows - Time taken: 18.44 seconds.
#
# 예시:
# 입력된 제목: HSo~" 러츠 ~탈리nn서f뛸 때보다 /미있어요
# 복원된 제목: GS칼텍스 러츠 이탈리아에서 뛸 때보다 재미있어요
#
# 입력된 제목: 鏮릎=부상s이CY /표팀~ r외7!속I|복Pq*비
# 복원된 제목: 무릎 부상 이재성 대표팀서 제외…소속팀 복귀 준비
#
# 입력된 제목: NQX에3_)2ih농WL"들8 J록슛 x도…막았鏜니 됐다
# 복원된 제목: NBA에서 벗겨진 농구화 들고 블록슛 시도…막았으니 됐다
#
#
# --------------------------------------------
# 결과 : 추신수 시g경기~o종^ 2j넷b타율|0.21u -- 추신수 경기에서 타율 0점대...부진 탈출
# --------------------------------------------
# Processed 48/1602 rows - Time taken: 18.30 seconds.
#
# 예시:
# 입력된 제목: X무게-<{스·부동$7f\ 5센湈呇…yX있x4*L;:$N조L
# 복원된 제목: 몸무게 보너스·부동산 지분 인센티브…재미있는 MLB계약 조건
#
# 입력된 제목: 4ZB닷Rl#C비蟭 M籒 자wX;승X이 !다
# 복원된 제목: MLB닷컴 오타비노 떠난 자리 오승환이 있다
#
# 입력된 제목: 배구 남녀繗nB煍c임도헌라바d니 胝독CB-서 짧0 V견c
# 복원된 제목: 배구 남녀 대표팀 임도헌라바리니 감독 보령서 짧은 상견례
#
#
# --------------------------------------------
# 결과 : #Ca유영준:왕웨이+ $직 조심스러워…h구 h 805+)내 -- 청년 CEO 유영준 왕웨이 만나 조심스러운 발언...환경 보호 강조
# --------------------------------------------
# Processed 49/1602 rows - Time taken: 22.01 seconds.
#
# 예시:
# 입력된 제목: pn: j< cpj 드4j k준호[G6^5공할까종{
# 복원된 제목: 자사주 매입 자신감 드러낸 조준호…G6 성공할까종합
#
# 입력된 제목: N?u엔5#인먼트 _분?,~4익 2`,/-=50% 증B
# 복원된 제목: NHN엔터테인먼트 2분기 영업익 149억원…50% 증가
#
# 입력된 제목: 이F8t`문GC 급u…G해 다단계 ; K월
# 복원된 제목: 이통사 방문판매 급증…올해 다단계 첫 추월
#
#
# --------------------------------------------
# 결과 : ip*한국사이버[제 U분기 영업익ux0u원?!.G$ 감소 -- 한국 사이버 보안 분기 영업이익 전년 대비 3억 감소. 4분기도 기대
# --------------------------------------------
# Processed 50/1602 rows - Time taken: 18.89 seconds.
#
# 예시:
# 입력된 제목: 터X9 시O아 진M…에"도안>i3의'샘 >騜 개시 선@8합
# 복원된 제목: 터키군 시리아 진격…에르도안 평화의 샘 작전 개시 선언종합
#
# 입력된 제목: 중<轩a일L7[r 아부\비DG1당 옥s관 -업W7
# 복원된 제목: 중동 유일 UAE 아부다비 北식당 옥류관 영업중단
#
# 입력된 제목: 중拇#원S로 X설J?조원 |筮 +r다
# 복원된 제목: 중러 원자로 건설 2조원 계약 맺는다
#
#
# --------------------------------------------
# 결과 : ~리비{3Qn'9 신분 변:+허용…의료u서로 사전w입p해야 -- 리비아 난민 신분변조 허용...해외 의료보험 사전가입 의무
# --------------------------------------------
# Processed 51/1602 rows - Time taken: 19.82 seconds.
#
# 예시:
# 입력된 제목: c0이스G너 올%/설 연휴 가pc해僇NL| ^가
# 복원된 제목: 스카이스캐너 올해 설 연휴 가족 해외여행객 증가
#
# 입력된 제목: 산천G축Z v작썰笹 경주 진짜 w.~ 싶u
# 복원된 제목: 산천어축제 창작썰매 경주 진짜 이기고 싶다
#
# 입력된 제목: D-aN 여행"qA권 산정7$s 들Z e쭉*3막바-w1려f0자q
# 복원된 제목: 주말 N 여행 호남권 산정상 물 들인 철쭉의 막바지 화려한 자태
#
#
# --------------------------------------------
# 결과 : 수능 6?'{="원)%&G울 문O서 h개한 \꽃Z -- 수능 시험원 관련 정부 대책 발표 울며 겨자 먹기로 서명한 학생들
# --------------------------------------------
# Processed 52/1602 rows - Time taken: 17.97 seconds.
#
# 예시:
# 입력된 제목: 긴綎재난지QU b |부금은q1천礒`2z%…지급액의~2%
# 복원된 제목: 긴급재난지원금 중 기부금은 2천782억원…지급액의 2%
#
# 입력된 제목: 언.위Y불m/ TM`거4]도9\11 제M
# 복원된 제목: 언중위 불공정 지방선거 보도 91건 제재
#
# 입력된 제목: "s,교眯9H}교X'9외"*OXL8d_ 일제A S영
# 복원된 제목: 전북 교육계 전교조 법외노조 취소 판결 일제히 환영
#
#
# --------------------------------------------
# 결과 : SHT 내비게s션cTW&/ 국민h,!p yi -- 스마트교통 내비게이션 서비스 국민 이용률 증가
# --------------------------------------------
# Processed 53/1602 rows - Time taken: 18.31 seconds.
#
# 예시:
# 입력된 제목: 충북p영하권 T위a瘠d최A膼3q5도
# 복원된 제목: 충북 영하권 추위…낮 최고 3∼5도
#
# 입력된 제목: :J판 LGU7俆월까지@*산`醈L yg.가f5Av특별전시R
# 복원된 제목: 게시판 LGU 8월까지 용산사옥서 구족화가 5인 특별전시회
#
# 입력된 제목: #}온 추위)전북k:저 영하 O.8@…2∼5㎝ 눈
# 복원된 제목: 돌아온 추위 전북 최저 영하 7.8도…2∼5㎝ 눈
#
#
# --------------------------------------------
# 결과 : 서울문고 N풍그U에 인수… f라인서점 교m영풍y양강d도로 -- 서울시문고 풍림에 450억 인수...교묘 서점과 시너지 효과 기대
# --------------------------------------------
# Processed 54/1602 rows - Time taken: 18.84 seconds.
#
# 예시:
# 입력된 제목: 0O회 국제啖U도嗧=융w3
# 복원된 제목: 제6회 국제주택도시금융포럼
#
# 입력된 제목: 민u+반연맹 }정규=c7脵철ohe(k동
# 복원된 제목: 민주일반연맹 비정규직 차별철폐 공동행동
#
# 입력된 제목: \북NR동해안권 5전I획 }소&|조7,惆沕 0Q(로
# 복원된 제목: 경북도 동해안권 발전계획 축소…7조7천억원 투자키로
#
#
# --------------------------------------------
# 결과 : 온*으Q 한방 바Z_를 느끼다…|천~한방D스N D20 -- 한방의 효능을 느끼는 특별한 체험...천년한방스파
# --------------------------------------------
# Processed 55/1602 rows - Time taken: 18.65 seconds.
#
# 예시:
# 입력된 제목: 유.? }2 생烺송E(阖~UT문 자막 L는다
# 복원된 제목: 유튜브 영어 생방송에 자동 영문 자막 붙는다
#
# 입력된 제목: 아이폰3(용} ^성@ 사용자y다 8켓몬고2즐(
# 복원된 제목: 아이폰 사용자 삼성폰 사용자보다 포켓몬고 즐겨
#
# 입력된 제목: 전력Z모 없는 무^/u6모h=Go성|G5규R
# 복원된 제목: 전력소모 없는 무전력 메모리 가능성 첫 규명
#
#
# --------------------------------------------
# 결과 : F% 전ZD78개 tn2a매\서 :<[+T 체험pjX ~련 -- 페이스북 전 세계 7억 개 계정 사용 현황 체험기
# --------------------------------------------
# Processed 56/1602 rows - Time taken: 17.67 seconds.
#
# 예시:
# 입력된 제목: PP르M론 {I스w)이/侵5유니폼B입는다…a<_rC
# 복원된 제목: 킹 르브론 제임스 레이커스 유니폼 입는다…4년 계약
#
# 입력된 제목: ;b헌[감독 `은郻선a.5자63 rt다…呋년 -eR진짜 승t
# 복원된 제목: 임도헌 감독 젊은 선수들 자신감 얻었다…내년 1월 진짜 승부
#
# 입력된 제목: '무6 보너스姦妳동산eW분 @c=브…재미있는eML梁계약 조P
# 복원된 제목: 몸무게 보너스·부동산 지분 인센티브…재미있는 MLB계약 조건
#
#
# --------------------------------------------
# 결과 : 멀티골 j순형 u로축구 pB그1 1"\운드FXVP -- 멀티골 존형욱 감독 축구 대표팀 주장 선발...1위 팀과 경기
# --------------------------------------------
# Processed 57/1602 rows - Time taken: 18.84 seconds.
#
# 예시:
# 입력된 제목: KT s터리 W감 .l로h,럭시xS9>nQ iY%吻더 ~2
# 복원된 제목: KT 배터리 절감 기술로 갤럭시 S9 최대 55% 더 쓴다
#
# 입력된 제목: 硰Kc레콤A트!|이 w국 서비j 개시
# 복원된 제목: SK텔레콤 트리페이 태국 서비스 개시
#
# 입력된 제목: 초신/ 竃a 3시간R만k[.S…최단기R
# 복원된 제목: 초신성 폭발 3시간 만에 관측…최단기록
#
#
# --------------------------------------------
# 결과 : LGh UIo]에"구글kO~fNP !T…G+[피커 없,H _용 -- LG UI에 구글 기능 통합...피처폰 없는 스마트폰 시대 개막
# --------------------------------------------
# Processed 58/1602 rows - Time taken: 19.01 seconds.
#
# 예시:
# 입력된 제목: 아이폰4:-^ j蛻링S현상悮K터리o게tS로 8화D(
# 복원된 제목: 아이폰8 잇단 스웰링 현상…배터리 게이트로 비화할까
#
# 입력된 제목: 황우|Jll복c.阠세포 미국+z허L`7
# 복원된 제목: 황우석 인간복제줄기세포 미국 특허 등록
#
# 입력된 제목: ~B%Ig湭 UAR로檷만傹P…3Dr영梌D입체^$티커 j와
# 복원된 제목: 직통령 펭수 UAR로 만난다…3D 영상·입체 스티커 나와
#
#
# --------------------------------------------
# 결과 : 종이 ~면 ~어도$삼z중공/ 3Dxp델로 설> s증받는다 -- 종이컵 사용해도 2중 구조로 안전성 증대...플라스틱 대체 기대
# --------------------------------------------
# Processed 59/1602 rows - Time taken: 19.07 seconds.
#
# 예시:
# 입력된 제목: *T 기8지니 >~똑똑};다1가P驦L 30만 돌v2O_
# 복원된 제목: KT 기가지니 더 똑똑해진다…가입자도 30만 돌파 쑥쑥
#
# 입력된 제목: LG전자 z지潺입DJ레질Xu선<T소기 $시
# 복원된 제목: LG전자 먼지흡입물걸레질 무선 청소기 출시
#
# 입력된 제목: 다재다Vh갤(~7nNP<처럼[쓰[`V,sS방송u{R다종a
# 복원된 제목: 다재다능 갤럭시S8 PC처럼 쓰고 VR 생방송도 한다종합
#
#
# --------------------------------------------
# 결과 : 올#%서5외i어s울h증 oIp자Ej역#o m -- 서울 올림픽공원서 드론 전시회 열려
# --------------------------------------------
# Processed 60/1602 rows - Time taken: 18.85 seconds.
#
# 예시:
# 입력된 제목: w구uO 세5g인여/협회Y 대NZWv{ 5무협약
# 복원된 제목: 배구협회 세계한인여성협회와 대표팀 지원 업무협약
#
# 입력된 제목: 일zF 번 ]+자…!자k구p대표팀Ak9하* 베테랑^;&
# 복원된 제목: 일 한 번 내보자…여자축구 대표팀 지탱하는 베테랑의 힘
#
# 입력된 제목: z시안게임j베트牘과Y4강4 M~Ihz범의 A부수 + .蛹.
# 복원된 제목: 아시안게임 베트남과 4강전 앞둔 김학범의 승부수 한 ...
#
#
# --------------------------------------------
# 결과 : ~학농구리- 8일 고려대중앙대 경pt 개막 -- 고려대 중앙대 농구 경기 208경기 개막 행사
# --------------------------------------------
# Processed 61/1602 rows - Time taken: 18.94 seconds.
#
# 예시:
# 입력된 제목: 미래Ly대우 엔씨1p트u桇출 <5 굳건J목"가↑
# 복원된 제목: 미래에셋대우 엔씨소프트 매출 1위 굳건…목표가↑
#
# 입력된 제목: rN:캣 맥Y5컨n롤aok'9qV신제품 골드 수,
# 복원된 제목: 두산밥캣 맥스 컨트롤 2019 혁신제품 골드 수상
#
# 입력된 제목: 보험{ 禢襕잔액 2r8\F]주택담#대燼 $가~전환
# 복원된 제목: 보험사 대출잔액 238조원…주택담보대출 증가 전환
#
#
# --------------------------------------------
# 결과 : D도t ,{2자 ;H대, 교육·j@y목적d<WsU허 -- 디지털 교육 플랫폼 'H대학교', 교육 목적 맞춤형 서비스 제공
# --------------------------------------------
# Processed 62/1602 rows - Time taken: 19.11 seconds.
#
# 예시:
# 입력된 제목: 湌1부·창의재+ Syw구활6z교사'구懼 ?집
# 복원된 제목: 미래부·창의재단 SW교구활용 교사연구회 모집
#
# 입력된 제목: ~재 v悢과uw찰에Uo통령 관y 수사7''제출X요6속보
# 복원된 제목: 헌재 특검과 검찰에 대통령 관련 수사기록 제출 요청속보
#
# 입력된 제목: |소lD선滦h출석하i 이q택
# 복원된 제목: 항소심2선고 출석하는 이%택
#
#
# --------------------------------------------
# 결과 : K^한국관광공사X업무y약@체결 -- 한국관광공단 업무협약 체결
# --------------------------------------------
# Processed 63/1602 rows - Time taken: 17.43 seconds.
#
# 예시:
# 입력된 제목: N럼프2또 런던'{R[h감|j표출 KT A앙w새)絎장 O요해
# 복원된 제목: 트럼프 또 런던시장에 악감정 표출 그는 재앙…새 시장 필요해
#
# 입력된 제목: 이" 탄도미K^C개발B%T상 q상q아냐 재확인
# 복원된 제목: 이란 탄도미사일 개발은 협상 대상 아냐 재확인
#
# 입력된 제목: 키신鲩h만난 )진. 亱中 소U-강|해 오%3婍%雀피해_
# 복원된 제목: 키신저 만난 시진핑 美中 소통 강화해 오해·오판 피해야
#
#
# --------------------------------------------
# 결과 : 프랑스 마N}의 이I 대\- G7 ;청설 c인 -- 프랑스 마크롱의 G20 발언 논란 G19 대신 청설 언급
# --------------------------------------------
# Processed 64/1602 rows - Time taken: 19.21 seconds.
#
# 예시:
# 입력된 제목: '이스북'읽는 QB :此피드s랭J劊FO영…낚시P사 불x익
# 복원된 제목: 페이스북 읽는 시간 뉴스피드 랭킹에 반영…낚시기사 불이익
#
# 입력된 제목: 공시Y가 賣람D蟇W@산妁시가격y|미h서B.
# 복원된 제목: 공시지가 열람은 부동산공시가격알리미에서..
#
# 입력된 제목: 금^vF심의a 전`회\
# 복원된 제목: 금융발전심의회 전체회의
#
#
# --------------------------------------------
# 결과 : 속(지역 도시 난개발L방C^zcv개정안 발의 놓d B등 -- 지역 도시난개발 방지 개정안 발의 논의
# --------------------------------------------
# Processed 65/1602 rows - Time taken: 18.02 seconds.
#
# 예시:
# 입력된 제목: 증c가 대G항!EKg해운z추敢{실 위험5출S경?敿합
# 복원된 제목: 증권가 대한항공 한진해운 추가부실 위험노출 경고종합
#
# 입력된 제목: (의선)(대차그룹8회장533…3세'8E`Mq<종합
# 복원된 제목: 정의선 현대차그룹 회장 된다…3세 경영 본격화종합
#
# 입력된 제목: e래픽N작년 Hp 1인당^보유종목수Wi.[b개
# 복원된 제목: 그래픽 작년 주식 1인당 보유종목수 4.27개
#
#
# --------------------------------------------
# 결과 : }독Q멈=선  데L수M원대[면~점·2p 인;도 무산 -- 독선적 경영 멈추라...데스크 수 millions 원대 면점 폐지 무산 2%
# --------------------------------------------
# Processed 66/1602 rows - Time taken: 19.19 seconds.
#
# 예시:
# 입력된 제목: D) 손이O'4트fg잡Ja~ 2荺록 Q는Q인공r^부S개발
# 복원된 제목: 로봇 손이 스마트폰 잡을 수 있도록 돕는 인공 피부 개발
#
# 입력된 제목: 弇혹의 N 鋇O베리G%cS입은 pG V3-
# 복원된 제목: 유혹의 색 라즈베리 로즈 입은 LG V30
#
# 입력된 제목: 추i의 노,아D /활c+-81 R값＋2\시간 }{趣菙
# 복원된 제목: 추억의 노키아폰 부활…49유로 헐값＋22시간 통화종합
#
#
# --------------------------------------------
# 결과 : y=sc럼*광합성하h f공장W 개발 -- 태양광 공장에서 효율적인 광합성을 돕기 위한 연구 개발 1
# --------------------------------------------
# Processed 67/1602 rows - Time taken: 18.02 seconds.
#
# 예시:
# 입력된 제목: 한'q물러眊 3 막` i겠다r文 호]qZ정J_파
# 복원된 제목: 한발 물러선 金 막지 않겠다…文 호남행 정면돌파
#
# 입력된 제목: 우병弰h언급(안B 6爑!령 Z보 행i로 돌6
# 복원된 제목: 우병우 언급 안한 朴대통령 안보 행보로 돌파
#
# 입력된 제목: 국민勐당o2{희t朴대Q|7저~ 7Q Q粉r=柏囬g 논란
# 복원된 제목: 국민의당 권은희 朴대통령 저격 풍자 SNS 포스터 논란
#
#
# --------------------------------------------
# 결과 : 與비박계 내일}"단'당…개혁보수신당E!당추진위 M동 -- 여당 비박계 tomorrow 단결과 개혁보수 신당 추진위원회 가동
# --------------------------------------------
# Processed 68/1602 rows - Time taken: 19.50 seconds.
#
# 예시:
# 입력된 제목: y9~용품,@집 %정d 담t 축구수집糖p 비YX)
# 복원된 제목: 축구 용품 수집 과정의 담은 축구수집가의 비밀창고
#
# 입력된 제목: 내nH#k화kNy지f전국| 비…f WrS찜9*위
# 복원된 제목: 내주날씨 화요일까지 전국에 비…주 후반 찜통더위
#
# 입력된 제목: V국=锢침 PE 최대@7도 뚝…주e까지 5쌀
# 복원된 제목: 전국 아침 기온 최대 7도 뚝…주말까지 쌀쌀
#
#
# --------------------------------------------
# 결과 : 신간 Z끗 g이`V자cJ법>{코뮤니3트?33 -- 새로운 공동체 활동 방법을 다룬 신간 서적
# --------------------------------------------
# Processed 69/1602 rows - Time taken: 18.02 seconds.
#
# 예시:
# 입력된 제목: 제21회虲울凸0훈대상 0钯"(문k|c…pc2보'鮡'
# 복원된 제목: 제21회 울산보훈대상 5개 부문 시상…경상일보 주관
#
# 입력된 제목: *R N絒 대학들 '[금 ]0El부j]P담 덜겠c
# 복원된 제목: 전북 주요 대학들 등록금 동결…학부모 부담 덜겠다
#
# 입력된 제목: 게시판 EBS_전방송 (k痘양성/1한 t*np
# 복원된 제목: 게시판 EBS대전방송 인재 양성 위한 업무협약
#
#
# --------------------------------------------
# 결과 : 땅 파= 코l나 격리시설 탈출한 외국인 청_서 VS -- 코로나 격리 시설 탈출 외국인 검거, 경찰과의 충돌로 부상당해
# --------------------------------------------
# Processed 70/1602 rows - Time taken: 17.59 seconds.
#
# 예시:
# 입력된 제목: ~시,&J I르7스스P전 j#jTG觎0&e로 @든o*o.R
# 복원된 제목: 아시안게임 키르기스스탄전 앞둔 김학범 스스로 만든 가...
#
# 입력된 제목: eR을熁O목하라Gw愼E월5컵d1p증된 예U7슈퍼스타
# 복원된 제목: 이들을 주목하라 U20월드컵의 검증된 예비 슈퍼스타
#
# 입력된 제목: u의v"한Z류현진 衆신수와O癱은qE y별< 3 같다
# 복원된 제목: 금의환향한 류현진 추신수와 같은 팀 특별할 것 같다
#
#
# --------------------------------------------
# 결과 : 전광인4없어도 한국전L FTV4컵서 현:캐피탈 격파종합 -- 4강에도 전광인도 없어도 종합 2위, 한국 남자 배구팀 캐피탈 격파
# --------------------------------------------
# Processed 71/1602 rows - Time taken: 18.65 seconds.
#
# 예시:
# 입력된 제목: f慸제M!당?S표5{첫槅삭b 감i@조국 vO,>여투쟁 승부수종합2Z
# 복원된 제목: 黃 제1야당 대표로 첫 삭발 감행…조국 반대 대여투쟁 승부수종합2보
#
# 입력된 제목: Yd장 들0서z 홍<J 지[
# 복원된 제목: 회견장 들어서는 홍준표 지사
#
# 입력된 제목: 올림q 韉*통7 f리w선수단z선3 기원
# 복원된 제목: 올림픽 朴대통령 우리 선수단 선전 기원
#
#
# --------------------------------------------
# 결과 : 朴t)령 北Ph각한 균s조짐…i}동요f가LU~Hj종합 -- 박근혜 대통령, 북한 급변사태 조짐에 동요...이사회 긴급 대응종합보도로 확인
# --------------------------------------------
# Processed 72/1602 rows - Time taken: 17.63 seconds.
#
# 예시:
# 입력된 제목: J5`\煾주?gM주 c&U자 ZV
# 복원된 제목: 기가레인 주당 1주 무상증자 결정
#
# 입력된 제목: 프럼e스트?21억IJ치]ya1~#간외e매=!결정
# 복원된 제목: 프럼파스트 21억원어치 자사주 시간외 매매 결정
#
# 입력된 제목: 구|t단M업WEJ영계획D원XZ D橔 `천1zNt
# 복원된 제목: 구미공단 업체 경영계획 원달러 환율 1천133원
#
#
# --------------------------------------------
# 결과 : 손경w ,J 회V e즈베fym관% 협력방안 9의 -- 삼성전자 회현동 지점 베트남 공장 협력 방안 모색 7가지
# --------------------------------------------
# Processed 73/1602 rows - Time taken: 18.36 seconds.
#
# 예시:
# 입력된 제목: 문 대R|M\정지a도67i$…지난주보) 3%`Jj90럽B합
# 복원된 제목: 문 대통령 국정지지도 74%…지난주보다 3%P 상승갤럽종합
#
# 입력된 제목: 이.삼B홍준圎ek나라 惴+T 때 바2Qy아7?3#
# 복원된 제목: 이순삼 홍준표는 나라 위급할 때 바로 잡아줄 후보
#
# 입력된 제목: j인제;충/을[>은B희<n 땅으+籦만들Dx충JsN<출마Q선U
# 복원된 제목: 이인제 충청을 젊은 희망의 땅으로 만들것 충남지사 출마 선언
#
#
# --------------------------------------------
# 결과 : _대통령·시도P]y일e리g언…지`이 고용-R 주역종합 -- 대통령·시장·도지사 일하기 좋은 일터 종합평가
# --------------------------------------------
# Processed 74/1602 rows - Time taken: 20.71 seconds.
#
# 예시:
# 입력된 제목: {S'?Q菍러{#?*uDU` 뛸R7D다W재미^어&
# 복원된 제목: GS칼텍스 러츠 이탈리아에서 뛸 때보다 재미있어요
#
# 입력된 제목: t로x. v삼g사 컬페;>6스트餒 k상QA체할櫚듯
# 복원된 제목: 프로농구 인삼공사 컬페퍼 햄스트링 부상…교체할 듯
#
# 입력된 제목: 월드컵L8I& A짜를 이Cc…신n용爘닮은꼴V뢰프..y
# 복원된 제목: 월드컵 짝퉁이 진짜를 이겼다…신태용 닮은꼴 뢰프...
#
#
# --------------------------------------------
# 결과 : 157㎞ 조:우 선동, _독%과Wk께PAG 5전i고> -- 조우석 기자의 선동적인 독설, 3전 2선승제
# --------------------------------------------
# Processed 75/1602 rows - Time taken: 18.92 seconds.
#
# 예시:
# 입력된 제목: r성수-후보자(위기라? B다u靵V"정)醥위L가磊S7
# 복원된 제목: 은성수 후보자 위기라고 하다 보면 정말 위기가 온다
#
# 입력된 제목: )양정:회담 꿈| 하나 소원%:하燑 +Pe영~棸
# 복원된 제목: 평양정상회담 꿈도 하나 소원도 하나 평화번영통일
#
# 입력된 제목: /椖8R미래=@관>A!n예고I|o술'v새 부-是종합
# 복원된 제목: 유영민 미래부장관 개혁 예고…새 술은 새 부대에종합
#
#
# --------------------------------------------
# 결과 : 발언하\ 박광E -- 박광석 장관 발언
# --------------------------------------------
# Processed 76/1602 rows - Time taken: 18.52 seconds.
#
# 예시:
# 입력된 제목: 貄지만yV타\ 狵안{!타- 0.x57
# 복원된 제목: 최지만 3타수 무안타…타율 0.257
#
# 입력된 제목: 예r받은 (바/아\45번 R ;라우e…감Px lLB钣Qa타전
# 복원된 제목: 예우받은 사바시아 45번 단 트라우트…감동의 MLB 올스타전
#
# 입력된 제목: gr]구D부皬부천X|산( 1{由무P)
# 복원된 제목: 프로축구2부 부천 안산과 11 무승부
#
#
# --------------------------------------------
# 결과 : 2자배구}대k팀*코7진 구성 완료…트R}너에 정기혁 -- 배구팀 코치진 7명 구성...정기혁 신임 감독 임명
# --------------------------------------------
# Processed 77/1602 rows - Time taken: 19.23 seconds.
#
# 예시:
# 입력된 제목: 충s 가마솥Q위 Xj:주(o 더D요
# 복원된 제목: 충북 가마솥더위 지속…주말도 더워요
#
# 입력된 제목: -마 l문赦…전Ff해赓욕Uo유;산 (e지 \렁
# 복원된 제목: 장마 때문에…전국 해수욕장 유명산 관광지 썰렁
#
# 입력된 제목: 이忾C q집0,U매일B\ v부G지)`리두면…;d 4*
# 복원된 제목: 이달의 편집상에 매일신문 공부까지 거리두면… 등 4편
#
#
# --------------------------------------------
# 결과 : 날씨-미z먼지 보통 수y…오후부터 xJ지고:곳곳 F12일 -- 미세먼지 보통 수준...낮부터 저녁까지 곳곳에 비
# --------------------------------------------
# Processed 78/1602 rows - Time taken: 17.90 seconds.
#
# 예시:
# 입력된 제목: OK 7정\C즌O마수'4 아치(홈런왕匡3<![\B
# 복원된 제목: SK 최정 시즌 마수걸이 아치…홈런왕 3연패 시동
#
# 입력된 제목: <E$Ke흥LuQ\6V1끝김J욱R@리/~달\다
# 복원된 제목: 월드컵 손흥민·황희찬 발끝김신욱 머리에 달렸다
#
# 입력된 제목: T?o|11회qA속 P드컵 CHB진y(0탈리아3菺OY)합
# 복원된 제목: 스페인 11회 연속 월드컵 본선 진출…이탈리아 PO행종합
#
#
# --------------------------------------------
# 결과 : 선두5도X공사*GS칼텍$^K;dhb현Q#i탈7m연승]합 -- 삼성전자, 글로벌 시장 선두...7개월 연속 매출 성장세
# --------------------------------------------
# Processed 79/1602 rows - Time taken: 18.93 seconds.
#
# 예시:
# 입력된 제목: MCC 전:T약zcc[운서들 계s만료O통Pk 부당해고
# 복원된 제목: MBC 전 계약직 아나운서들 계약만료 통보는 부당해고
#
# 입력된 제목: 민주fXHND[mY] ]BA폐 H货행동
# 복원된 제목: 민주일반연맹 비정규직 차별철폐 공동행동
#
# 입력된 제목: i시판荻YR*T 의<도 d1v<서UCV7
# 복원된 제목: 게시판 KIST 의학도 대상 리서치 캠프
#
#
# --------------------------------------------
# 결과 : 수( 이F[I인an고3 수<생N확L 잇I]…교7 당국5.각 -- 학생 선수들의 학사관리 문제에 대한 교육부 당국의 조치
# --------------------------------------------
# Processed 80/1602 rows - Time taken: 17.19 seconds.
#
# 예시:
# 입력된 제목: SK )S1파B@너지서비스d지분 IW 절차寉진행
# 복원된 제목: SK ES 파주에너지서비스 지분 매각 절차 진행
#
# 입력된 제목: Z융~장寔충격 -: 소N국*Tuh 낙= (고 환q4@하o
# 복원된 제목: 금융시장 충격 일단 소강국면…주가 낙폭 줄고 환율도 하락
#
# 입력된 제목: 케이에스피b전 Im이사+배]e혐의n 불e속 기소
# 복원된 제목: 케이에스피 전 대표이사 배임 혐의로 불구속 기소
#
#
# --------------------------------------------
# 결과 : 20T9년s제1회 외K인투자~정@협의회 -- 제15회 외국인투자 촉진대회 개최
# --------------------------------------------
# Processed 81/1602 rows - Time taken: 17.17 seconds.
#
# 예시:
# 입력된 제목: J가莄O정 부당…구_YSo린<A6·인F "p 대4
# 복원된 제목: 평가 과정 부당…구설 휘말린 AI·인간 번역 대결
#
# 입력된 제목: 昢T 4가지fr摐일부@ AI M!서7/도%5C종U
# 복원된 제목: KT 기가지니 내일부터 AI 금융서비스도 척척종합
#
# 입력된 제목: C^a'플e/f隬구- 스K트폰B가@대a 임박
# 복원된 제목: 삼성·애플·LG·구글 스마트폰 가을대전 임박
#
#
# --------------------------------------------
# 결과 : 게$판,QK텔d크_아이폰4O아이U}<TyF매 이벤트 -- 갤럭시 S21 팬 에디션 출시, 아이폰 13 이벤트 임박 2022년
# --------------------------------------------
# Processed 82/1602 rows - Time taken: 18.40 seconds.
#
# 예시:
# 입력된 제목: HD부傂us자箱특6#}과위#장 간\,
# 복원된 제목: 중기부 규제자유특구 분과위원장 간담회
#
# 입력된 제목: O공정=Pz'x골z기* 공A위 본C 직( 조^b는다
# 복원된 제목: 불공정 혐의 단골 기업 공정위 본부 직접 조사받는다
#
# 입력된 제목: Z급재난権원O@eT0부[은 Hi783H원b지급액/bA%
# 복원된 제목: 긴급재난지원금 중 기부금은 2천782억원…지급액의 2%
#
#
# --------------------------------------------
# 결과 : 모멘트 학교 급식U4칸막이lx곡 -- 학교급식 칸막이 설치 의무화 논란
# --------------------------------------------
# Processed 83/1602 rows - Time taken: 18.35 seconds.
#
# 예시:
# 입력된 제목: 정끝별|Mtln말하)t패緦디3dY5l 중심U8현방법
# 복원된 제목: 정끝별 시인이 말하는 패러디…이 시대 중심 표현방법
#
# 입력된 제목: 妤* 큰 --w첫 Y제b묵비L날Fcw3 h:
# 복원된 제목: 수묵 큰 잔치 첫 국제수묵비엔날레 9월 개막
#
# 입력된 제목: 玦작 돼버린,L광수JQ설: 곧 <온Q
# 복원된 제목: 유작 돼버린 마광수 소설집 곧 나온다
#
#
# --------------------------------------------
# 결과 : 올해iEIDFO*상에 멀리 개 짖는 소w가 들"S -- 올 여름 세계적인 영화 '개 짖어 소가 들리는 집' 상영
# --------------------------------------------
# Processed 84/1602 rows - Time taken: 17.53 seconds.
#
# 예시:
# 입력된 제목: 상장M신작TA,?S경4에 넷마rb첫b깜짝9K너스
# 복원된 제목: 상장·신작 대박 겹경사에 넷마블 첫 깜짝 보너스
#
# 입력된 제목: 3l픽8전국C주g 매매 \래u 추v
# 복원된 제목: 그래픽 전국 주택 매매 거래량 추이
#
# 입력된 제목: _0m!+L( 상반기 8e%妉燔성·환금H ,k다
# 복원된 제목: 거래소 ELS 상반기 상장…안정성·환금성 높인다
#
#
# --------------------------------------------
# 결과 : ?씨D m년 h업8 16<K*…h4.8%3 -- 기업 M&A 5년 간 20% 성장률...올해도 강세 전망
# --------------------------------------------
# Processed 85/1602 rows - Time taken: 17.05 seconds.
#
# 예시:
# 입력된 제목: i기_s전역\미세먼= n逻보…야雍/동)자KNu
# 복원된 제목: 경기도 전역 미세먼지 주의보…야외활동 자제종합
#
# 입력된 제목: O%6톡 중v인의 눈q로 <M,반도 정세 9/7
# 복원된 제목: 사진톡톡 중국인의 눈으로 본 한반도 정세 인물화
#
# 입력된 제목: 미辽F# 유r'·O제원'사진MX기q 속, 푼;q
# 복원된 제목: 미술소식 유동훈·이제원 사진전 기억 속의 푼크툼
#
#
# --------------------------------------------
# 결과 : !대+화점 팝 pvhv`V트Y랩 진T -- 대형마트 팝마켓 인기 상품 모음전 진검승부
# --------------------------------------------
# Processed 86/1602 rows - Time taken: 17.39 seconds.
#
# 예시:
# 입력된 제목: 천h배+/일\Y>Bp판…O+Fc 野 연대갈V 湩대V铰
# 복원된 제목: 천정배 내일 安과 담판…국민의당 野 연대갈등 중대기로
#
# 입력된 제목: 朴대X령"한0_기업인에 誓동%력9당w
# 복원된 제목: 朴대통령 한러 기업인에 극동협력 당부
#
# 입력된 제목: [상 B출彚터 퇴장>지…e경蝲 원내대표 파Q만oU1y
# 복원된 제목: 영상 선출부터 퇴장까지…나경원 원내대표 파란만장 1년
#
#
# --------------------------------------------
# 결과 : xW리 a)엔 예비후0V사전여론조사 결과 유출 논c -- Xavier Lee 예비후보 사전여 론조사 유출 논란
# --------------------------------------------
# Processed 87/1602 rows - Time taken: 17.98 seconds.
#
# 예시:
# 입력된 제목: Yl준e원장mEU犲IX稈공지5鬍종합g구%? 거듭나겠다
# 복원된 제목: 김명준 원장 ETRI 인공지능 종합연구소로 거듭나겠다
#
# 입력된 제목: .暐>바일"어P신x+撓 蠅R 반)Z요금제 ]5
# 복원된 제목: 헬로모바일 어르신 대상 평생 반값 요금제 출시
#
# 입력된 제목: Z성·D플O彌G·+글M스마트폰 =o대전 W박
# 복원된 제목: 삼성·애플·LG·구글 스마트폰 가을대전 임박
#
#
# --------------------------------------------
# 결과 : 삼성 빅스. 개발자데KS1B월 서울B 첫 +최 -- 삼성전자 개발자대회 9월 15일 서울서 개최
# --------------------------------------------
# Processed 88/1602 rows - Time taken: 17.38 seconds.
#
# 예시:
# 입력된 제목: 구글 3j대9-y캐스/.출^&灠세*아이앤씨 단\ d매종합
# 복원된 제목: 구글 3세대 크롬캐스트 출시…신세계아이앤씨 단독 판매종합
#
# 입력된 제목: O로모-일 어르( 대상 "생e반값摡요M邯 출a
# 복원된 제목: 헬로모바일 어르신 대상 평생 반값 요금제 출시
#
# 입력된 제목: 가상화JVV기( 악a床嗺 기z];섬웨r/신5S帒.7배↑
# 복원된 제목: 가상화폐 인기에 악성코드 기승…랜섬웨어 신고 3.7배↑
#
#
# --------------------------------------------
# 결과 : 떼었S 붙였다 액세서리Y 스마C폰 업U레이드 -- 삼성 스마트폰 액세서리 업그레이드 출시, 사용자 편의성 강조
# --------------------------------------------
# Processed 89/1602 rows - Time taken: 18.26 seconds.
#
# 예시:
# 입력된 제목: KTi더욱E작~지고 0결해진gA| TV鐶기가지a2 출|
# 복원된 제목: KT 더욱 작아지고 간결해진 AI TV 기가지니2 출시
#
# 입력된 제목: t가kmT 부8…구qP휘j린hA|拐인간 번역E樬결
# 복원된 제목: 평가 과정 부당…구설 휘말린 AI·인간 번역 대결
#
# 입력된 제목: KT ~y 혜5c2V%}7l인kkZ@ 1즌--,입
# 복원된 제목: KT 할인 혜택 2배 더블할인 멤버십 시즌제 도입
#
#
# --------------------------------------------
# 결과 : 알림톡 무단 +송·pRL,5출 $카(*DF징q -- 알림톡 불법 전송 혐의로 논란, 개인정보 보호법 위반 의혹 제기
# --------------------------------------------
# Processed 90/1602 rows - Time taken: 18.13 seconds.
#
# 예시:
# 입력된 제목: :미圄D검언유? 책C론 mn돌파…(vT 고k·垢성윤 신임종합
# 복원된 제목: 추미애 검언유착 책임론 정면돌파…윤석열 고립·이성윤 신임종합
#
# 입력된 제목: j;=당C$/희妙朴대통령釷저격 풍자 S黏S 포M터Cc란
# 복원된 제목: 국민의당 권은희 朴대통령 저격 풍자 SNS 포스터 논란
#
# 입력된 제목: h岕하는 ;N부 KU
# 복원된 제목: 출근하는 통일부 장관
#
#
# --------------------------------------------
# 결과 : # 친박 원내L표Oi보\유Z G단B화J홍문<.8$>도T종합 -- 친박 원내대표 후보 옥중 서신 공개 논란...국민의힘 당대표 후보군 종합
# --------------------------------------------
# Processed 91/1602 rows - Time taken: 18.08 seconds.
#
# 예시:
# 입력된 제목: 알함n라 궁전의 !억 S:제 대본d\예鍆판鈞
# 복원된 제목: 알함브라 궁전의 추억 무삭제 대본집 예약판매
#
# 입력된 제목: 크루I 관광T용z반나8 부산z해4c트레킹 )\9개발
# 복원된 제목: 크루즈 관광객용 반나절 부산 해안 트레킹 상품 개발
#
# 입력된 제목: 베Bj欳러_;:의 ~도 #i 7개!鰃만에m^위"올l
# 복원된 제목: 베스트셀러 언어의 온도 출간 7개월 만에 1위 올라
#
#
# --------------------------------------------
# 결과 : 도자기g작품_E상O%{$람객들 -- ```
# --------------------------------------------
# Processed 92/1602 rows - Time taken: 13.64 seconds.
#
# 예시:
# 입력된 제목: %7e 선언w문재인蔥대`령,0,MBs
# 복원된 제목: 판문점 선언 문재인 대통령 발표 전문
#
# 입력된 제목: 與縳부 핵D장贞xH(LR드M배치도 다Q c론화
# 복원된 제목: 與내부 핵무장론 탄력…사드 배치도 다시 공론화
#
# 입력된 제목: aB$5철도[공동z; 내주 G작c남9관@p큰殠-狥
# 복원된 제목: 이해찬 철도 공동조사 내주 시작…남북관계 큰 변화
#
#
# --------------------------------------------
# 결과 : 분당X'k gIdi}X'3·1 야ekK대^)t대립 -- 분당 3.1 운동 기념대회 개최...대동단결 촉구
# --------------------------------------------
# Processed 93/1602 rows - Time taken: 17.34 seconds.
#
# 예시:
# 입력된 제목: 추v애2T언.[ V사 m의사r l표 %의pwP-돼
# 복원된 제목: 추미애 검언유착 수사 피의사실 공표 혐의로 고발돼
#
# 입력된 제목: G주硟m생 h정한=7iu회]%簎V라…한洊^4O`장
# 복원된 제목: 민주 민생 걱정한다면 국회 복귀하라…한국 적반하장
#
# 입력된 제목: 文대통령[베트B 欯"기,}_R|-회c3U1H와gd면@Wm{보
# 복원된 제목: 文대통령 베트남 당서기장 만나…국회의장·총리와도 면담종합2보
#
#
# --------------------------------------------
# 결과 : 김정은 $향gIx x산시 za -- 북한 김정은 상하이 방문
# --------------------------------------------
# Processed 94/1602 rows - Time taken: 18.34 seconds.
#
# 예시:
# 입력된 제목: 한투=정부 <책勅* ~t 전.A경l하강q"&에P1정Q
# 복원된 제목: 한투 정부 정책방향 소폭 전환…경기하강 방어에 긍정적
#
# 입력된 제목: CJ EM U레C<엔{'지분(<^@ 인수c추*
# 복원된 제목: CJ EM 플레디스엔터 지분 51% 인수 추진
#
# 입력된 제목: 코W롱플라스틱抝1霼기b醥9 &업익C靨I억@…1H,翏$
# 복원된 제목: 코오롱플라스틱 1분기 연결 영업익 58억원…138%↑
#
#
# --------------------------------------------
# 결과 : [반기 전}FjQQ 74Q여z…L년보~ 3.1%↓ -- 삼성바이오로직스 반기 실적 전년 대비 4.9% 감소
# --------------------------------------------
# Processed 95/1602 rows - Time taken: 19.19 seconds.
#
# 예시:
# 입력된 제목: SK(vSW파주에너지서비m C분1函각孰절W+?{
# 복원된 제목: SK ES 파주에너지서비스 지분 매각 절차 진행
#
# 입력된 제목: 원c러T환율w나흘째<상9
# 복원된 제목: 원달러 환율 나흘째 상승
#
# 입력된 제목: 우리Gjv주 l\거래소 신憋*상j
# 복원된 제목: 우리금융지주 한국거래소 신규 상장
#
#
# --------------------------------------------
# 결과 : S.수협은. 공공주택8</보)금 &보!y8출: -- 수협은행 공공임대주택 8차 모집 공고
# --------------------------------------------
# Processed 96/1602 rows - Time taken: 16.77 seconds.
#
# 예시:
# 입력된 제목: /시판M자랑TH운D衶hw론}wz GS}D&숙1
# 복원된 제목: 게시판 자랑스러운 한양언론인상에 임철순·이숙영
#
# 입력된 제목: >1부)5제F유특구 분R위원# //t
# 복원된 제목: 중기부 규제자유특구 분과위원장 간담회
#
# 입력된 제목: 전m교]청娿8+砩54:까-Z학생m毼h선P 폭력,해{실U조사
# 복원된 제목: 전북교육청 8월 14일까지 학생 운동선수 폭력피해 실태조사
#
#
# --------------------------------------------
# 결과 : 사법부 판결…불*:6U@Jx~(s }H AI.6f4,X터 -- 법원 판결 관련 AI 기술 사용 여부 논란
# --------------------------------------------
# Processed 97/1602 rows - Time taken: 18.57 seconds.
#
# 예시:
# 입력된 제목: 개(사hL는4류'인TyfD
# 복원된 제목: 개회사 하는 류희인 본부장
#
# 입력된 제목: 葓 오BMD0투h`막*v라…4파전慖승{ 5가름
# 복원된 제목: 與 오늘 전대투표 막 올라…4파전 승자 판가름
#
# 입력된 제목: -의종Xqw경환 \북 qw서V&LW풀{다 *회
# 복원된 제목: 백의종군 최경환 경북 모임서 족쇄 풀렸다 소회
#
#
# --------------------------------------------
# 결과 : 최고V원중9의원@{FU*에U\;x하는6A교안 -- 국회의장 후보 선출 최고위원장 중천협의회 의장 선출 협의
# --------------------------------------------
# Processed 98/1602 rows - Time taken: 17.86 seconds.
#
# 예시:
# 입력된 제목: 1린턴재단 M폭풍Rb…J亝$ vs 7\프 지지8_)hp^@좁0져
# 복원된 제목: 클린턴재단 후폭풍인가…힐러리 vs 트럼프 지지율 3%p로 좁혀져
#
# 입력된 제목: 그리3剹조만^ }F0o 국고; 발행0구제금J 이후 처음
# 복원된 제목: 그리스 조만간 10년물 국고채 발행…구제금융 이후 처음
#
# 입력된 제목: 중~ 퀄컴 이眥r:U슨도 vK점 위반b肄사
# 복원된 제목: 중국 퀄컴 이어 에릭슨도 반독점 위반 조사
#
#
# --------------------------------------------
# 결과 : 中[정u 지방W민0투Ad실태K6L}착5 -- 중국 지방정부 재정 악화 실태 조사 착수
# --------------------------------------------
# Processed 99/1602 rows - Time taken: 22.55 seconds.
#
# 예시:
# 입력된 제목: 남%의 과도/ 사23F숨 막x…@ZA서 아h L혼청구
# 복원된 제목: 남편의 과도한 사랑에 숨 막혀…UAE서 아내 이혼청구
#
# 입력된 제목: 강원CBS $T~i`?%h8일 착공…鏚z월 완공
# 복원된 제목: 강원CBS 사옥·선교센터 8일 착공…11월 완공
#
# 입력된 제목: 고대6 전SMBS瘧G장 a`vfLY소송"지赫 패소
# 복원된 제목: 고대영 전 KBS 사장 해임 불복 소송냈지만 패소
#
#
# --------------------------------------------
# 결과 : S9XOC카cO트6온라인 F개강좌 공동 개설 -- 서울대 온라인 강좌 공동 개발 개설 시작
# --------------------------------------------
# Processed 100/1602 rows - Time taken: 17.94 seconds.
# Checkpoint saved at row 100.
#
# 예시:
# 입력된 제목: YC컬J아리 아-n2뮤지컬_& <구 =騑순
# 복원된 제목: 뮤지컬 아리 아라리·뮤지컬 내 친구 유관순
#
# 입력된 제목: 장미의 eXi"悫K扠입{니櫍(v61oX호b
# 복원된 제목: 장미의 이름 새 옷 입히니 젊은 독자 호응
#
# 입력된 제목: 예스2t众우8가 사랑한 u4宆\ 呖鵻들W부+서 전시
# 복원된 제목: 예스24 우리가 사랑한 24인의 작가들 부산서 전시
#
#
# --------------------------------------------
# 결과 : 그C픽)서울9s1l 일강&-H-이 -- 경기픽 서울 일강의 역사와 현대
# --------------------------------------------
# Processed 101/1602 rows - Time taken: 18.46 seconds.
#
# 예시:
# 입력된 제목: "x ( +행#(d[ P득한+찰eb수…,편단伙+무궁-
# 복원된 제목: 주말 N 여행 강원권 쫀득한 찰옥수수…일편단심 무궁화
#
# 입력된 제목: U9R.5대}재즈클+!로 변한 k연!
# 복원된 제목: 1930년대 재즈클럽으로 변한 공연장
#
# 입력된 제목: 예술颦전h i일 yCw저7~7시30분k로f{N긴2
# 복원된 제목: 예술의전당 평일 공연 저녁 7시30분으로 앞당긴다
#
#
# --------------------------------------------
# 결과 : (말\N 여행 aiq *#의 q…e을 반3는 ?딧M"<1짝 -- 여행 중 만난 친구와의 추억을 다시 읽다
# --------------------------------------------
# Processed 102/1602 rows - Time taken: 18.79 seconds.
#
# 예시:
# 입력된 제목: &징주 삼성vDv 0적 !VW1~.종합
# 복원된 제목: 특징주 삼성SDI 실적 개선에 강세종합
#
# 입력된 제목: W우건설:업e행P=반^장7>Lhr…|78.지z
# 복원된 제목: 대우건설산업은행 동반성장펀드 조성…협력사 지원
#
# 입력된 제목: 국제유가·x물가勑…올R n업경-`5rnZ%8o소+m3
# 복원된 제목: 국제유가·곡물가↓…올해 농업경영비 3.3% 감소 전망
#
#
# --------------------------------------------
# 결과 : e5 >사채 @행V0.9조원…Or대비O55z↑ -- 회사채 발행 9.5조 원...전년 대비 5.6% 증가
# --------------------------------------------
# Processed 103/1602 rows - Time taken: 18.14 seconds.
#
# 예시:
# 입력된 제목: @센x전G훈(,鸸}`=6일d)국…1프 蛽l@d 신재영Ps지&
# 복원된 제목: 넥센 전지훈련 마치고 6일 귀국…캠프 MVP는 신재영·김지수
#
# 입력된 제목: GZJ텍스 樣?KT업은m과C세i1이나연;이고은 A레a드
# 복원된 제목: GS칼텍스 IBK기업은행과 세터 이나연↔이고은 트레이드
#
# 입력된 제목: 0K:q0 시K.sa걸Q 아치…홈런p 3L패 시9
# 복원된 제목: SK 최정 시즌 마수걸이 아치…홈런왕 3연패 시동
#
#
# --------------------------------------------
# 결과 : 1이트삭oY:수 그S달 영입…4년- 7천34K= 달러 -- 이탈리아 축구팀, 그 달 영입 선수와 4년간 83억 5천만
# --------------------------------------------
# Processed 104/1602 rows - Time taken: 21.54 seconds.
#
# 예시:
# 입력된 제목: 이란 nz력+澿 V르i서Z우EP?농L]{| 5%n지 r릴 것
# 복원된 제목: 이란 원자력청장 포르도서 우라늄 농축 농도 5%까지 올릴 것
#
# 입력된 제목: u엔 o가踡aU국경지d s민|학대 HT 獽峫
# 복원된 제목: 유엔 헝가리에 국경지대 난민 학대 조사 촉구
#
# 입력된 제목: 필J핀 *e장관r몰0 군부鑕K _Qi3h4설 F치 E2厲oP昷
# 복원된 제목: 필리핀 국방장관 몰래 군부대에 中 통신 시설 설치 허용…재검토
#
#
# --------------------------------------------
# 결과 : 美 미네소타r州H람M장 입구H 2격d 명 부상 -- 미국 미네소타주 하람 목사 입구서 3명 부상 사고 발생
# --------------------------------------------
# Processed 105/1602 rows - Time taken: 18.04 seconds.
#
# 예시:
# 입력된 제목: i언론 *iF에 E\격…北과 다[ 게 언론Q 자유g B7
# 복원된 제목: 美언론 트럼프에 대반격…北과 다른 게 언론의 자유와 책임
#
# 입력된 제목: 이란N인공위성mb사s 폭r:o고 자인…d6K\함
# 복원된 제목: 이란 인공위성 발사체 폭발 사고 자인…기술 결함
#
# 입력된 제목: g 오h해P유조선Ng 배후z이란^:목hXc,S!Psd喍f
# 복원된 제목: 美 오만해 유조선공격 배후 이란 지목…이란 파병하려 날조
#
#
# --------------------------------------------
# 결과 : \페이오k중동서".]Vx국fr동]Cr구…이란B고. 강L종Q -- 폼페이오 중동서 미국 외교 강화...이스라엘과 협력 증진
# --------------------------------------------
# Processed 106/1602 rows - Time taken: 18.28 seconds.
#
# 예시:
# 입력된 제목: 베스트셀揻*A셜旑Ex"입소문)탄 에세이8인)
# 복원된 제목: 베스트셀러 소셜미디어 입소문 탄 에세이 인기
#
# 입력된 제목: )5rGF전* Mba내9z賋 50K100㎜ }
# 복원된 제목: 충북 장마전선 영향…내일까지 50∼100㎜ 비
#
# 입력된 제목: 頠#Ut_전 15 h너[ 조K eU여성도85백Q선
# 복원된 제목: 400년 전 일본 건너간 조선 첫 여성도공 백파선
#
#
# --------------------------------------------
# 결과 : 명! 옮p 는 즐Y움…필사 3문.지 문u^q간 -- 명상의 즐거움... 필사 20분 매일 실천하기
# --------------------------------------------
# Processed 107/1602 rows - Time taken: 17.78 seconds.
#
# 예시:
# 입력된 제목: t채%WXH("T]O쇼크…주식 빨리?살 필요nd없다
# 복원된 제목: 이채원 부사장 짧은 쇼크…주식 빨리 살 필요는 없다
#
# 입력된 제목: d대차 M)차僛DW;M\ 30珘/5T매수
# 복원된 제목: 현대차 현대차증권 MMT 300억원 매수
#
# 입력된 제목: 거-소 E?I 상z* 상M…안Q성&환금e 堀인Y
# 복원된 제목: 거래소 ELS 상반기 상장…안정성·환금성 높인다
#
#
# --------------------------------------------
# 결과 : 한sS3 파Sr사]&동반성장 협X식 -- 한국수자원공사 동반성장 협약식 개최
# --------------------------------------------
# Processed 108/1602 rows - Time taken: 17.76 seconds.
#
# 예시:
# 입력된 제목: H지b 1리i아라{·뮤지2G绻 친구H0관순
# 복원된 제목: 뮤지컬 아리 아라리·뮤지컬 내 친구 유관순
#
# 입력된 제목: x} 따라wT간여{pm.s…/M VaM Z&d O';개막
# 복원된 제목: 금강 따라 시간여행 떠나요…공주 석장리 구석기 축제 개막
#
# 입력된 제목: z'{q전!4ik먼h 주의M-야외활동愒자>종합
# 복원된 제목: 경기도 전역 미세먼지 주의보…야외활동 자제종합
#
#
# --------------------------------------------
# 결과 : 한국>Q/아/1i3명N키 m일본r의Q이+기…연극H={ -- 한국인 30명이 일본의 관광객으로 위장해 기획된 연극
# --------------------------------------------
# Processed 109/1602 rows - Time taken: 19.22 seconds.
#
# 예시:
# 입력된 제목: 네이버A인공지능`로鏿식X 예p*=화 받_SA2雰콜,q]
# 복원된 제목: 네이버 인공지능으로 식당 예약 전화 받는 AI 콜 공개
#
# 입력된 제목: i계 첫 Rg靬축s 월#컵 .`.ST魴vx막…12|軕c2&팀g참가
# 복원된 제목: 세계 첫 AI 축구 월드컵 KAIST서 개막…12개국 29팀 참가
#
# 입력된 제목: 알뜰폰 4!감?커진다Qu`헬k 사업자z,와`마i[퇴疇j2V
# 복원된 제목: 알뜰폰 위기감 커진다…CJ헬로 사업자협회와 마찰탈퇴종합2보
#
#
# --------------------------------------------
# 결과 : LGR 러0 타사 고객d대상Wg럭시S8 =험단Mu~ -- LG전자, 타사고객 대상 갤럭시 S8 할인 행사 진행
# --------------------------------------------
# Processed 110/1602 rows - Time taken: 21.96 seconds.
#
# 예시:
# 입력된 제목: 커지는 'PY I} 보안결함…PBOF$스마*폰도 H치OR종합
# 복원된 제목: 커지는 CPU 칩셋 보안결함…PC 외 스마트폰도 패치해야종합
#
# 입력된 제목: 네이G-LGL@津K 장{岧d zI스>kX음원 @용! Gh
# 복원된 제목: 네이버·LGU 지체 장애인에 AI스피커·음원 이용권 전달
#
# 입력된 제목: `카d~터프l이=!출범;rf 대표 기`zE{T 플랫폼 9V
# 복원된 제목: 카카오엔터프라이즈 출범…국내 대표 기업형 IT 플랫폼 목표
#
#
# --------------------------------------------
# 결과 : 사T인터l7신G Y v3투n해 미래 먹거리>o\x -- 삼성 AI 연구센터 신소재 개발로 미래 산업 먹거리 확보
# --------------------------------------------
# Processed 111/1602 rows - Time taken: 18.51 seconds.
#
# 예시:
# ...
# 결과 : :한금투 자동차 업/ 1분기부k5실적 점진?|I선 -- 한국투자증권 자동차 3분기에 영업이익 전년 대비 400억 원 증가 전망
# --------------------------------------------
# Processed 1566/1602 rows - Time taken: 22.05 seconds.
#
# 예시:
# 입력된 제목: Kk'연말연시 맞B Y트f크 특별(책,마'
# 복원된 제목: KT 연말연시 맞아 네트워크 특별대책 마련
#
# 입력된 제목: 삼성I2분x)yH 스屶XU 遜유m曧t위 Nx다^중국;7추P
# 복원된 제목: 삼성 2분기 세계 스마트폰 점유율 1위 지켰다…중국 맹추격
#
# 입력된 제목: 삼성·애플kEG·구r ]마트`倇가을대전 鿩Q
# 복원된 제목: 삼성·애플·LG·구글 스마트폰 가을대전 임박
#
#
# --------------------------------------------
# 결과 : L0 G6:,물사진R유출…둥tymz리 화면·얇B 베T 특징 -- LG 6월 스마트폰 사진 유출...얇고 강력한 성능 특징 t
# --------------------------------------------
# Processed 1567/1602 rows - Time taken: 17.37 seconds.
#
# 예시:
# 입력된 제목: 지각q입1V 남! 선수'驹] 儉Y<
# 복원된 제목: 지각 입장한 남북 선수단 그 사연은
#
# 입력된 제목: 최지만 8즌&0 37타fc아리 통^으芛厌燄체
# 복원된 제목: 최지만 시즌 첫 3루타…종아리 통증으로 교체
#
# 입력된 제목: 여자농H Kz국민h8 E0h?B019 S즌(H11Og;;:e
# 복원된 제목: 여자농구 KB국민은행 20182019 시즌권 11일부터 판매
#
#
# --------------------------------------------
# 결과 : ~ 전 앞둔eW재 감98T이 부K되지만  4로 승부수 -- 총선을 앞둔 재경지역 후보들의 전략 대결 4가지
# --------------------------------------------
# Processed 1568/1602 rows - Time taken: 18.05 seconds.
#
# 예시:
# 입력된 제목: M캘리V e대-관3장虔3J暕수曦수<| 애{,오0마TtH 논란
# 복원된 제목: 스캘리아 美대법관 장례식 엄수 수천명 애도…오바마 불참 논란
#
# 입력된 제목: M한 사이버 공격4Gchd#v^;1O}鈴j1儶억 탈8종합
# 복원된 제목: 북한 사이버 공격 집단 세계 은행들 상대 1천억 탈취종합
#
# 입력된 제목: 힘"얻는 시k+ 미` 미當딜 @w·해외9Ks壪e B:JED종합
# 복원된 제목: 힘 얻는 시진핑 미중 미니딜 성사·해외순방 통해 입지 다져종합
#
#
# --------------------------------------------
# 결과 : ;가 프리다a 사상 이해 안돼…벌@ =신 주멕시7J美대사 -- 가이트하우스 미군 아시아태평양 사령관 사상 존중 안 돼...신흥국 방문 중 미국대사 발언
# --------------------------------------------
# Processed 1569/1602 rows - Time taken: 20.19 seconds.
#
# 예시:
# 입력된 제목: 靑ra釶W-lg;k면e도4경z위축 고민은b계e
# 복원된 제목: 靑 청렴사회 공감하면서도 경제위축 고민은 계속
#
# 입력된 제목: 평양정~.담苯삼지%E6jP착한 bj대\鈅?,외
# 복원된 제목: 평양정상회담 삼지연공항 도착한 문 대통령 내외
#
# 입력된 제목: =胣리2鉼W 폭발한>상임{전국위·전鉍3는"어떤 H=
# 복원된 제목: 새누리 갈등 폭발한 상임 전국위·전국위는 어떤 기구
#
#
# --------------------------------------------
# 결과 : ^S 묘Z f막식.2:일}b행…8주주의·z도5문#새e -- 세계경제 포럼 개막식 2일차...주주총회 및 투자설명회
# --------------------------------------------
# Processed 1570/1602 rows - Time taken: 18.36 seconds.
#
# 예시:
# 입력된 제목: 부산v제코l디.W티벌V 참여합니다
# 복원된 제목: 부산국제코미디페스티벌에 참여합니다
#
# 입력된 제목: ]복 입-+^?IB황4EI9타면K요금 +'5 泖}
# 복원된 제목: 한복 입고 영산강 황포돛배 타면…요금 50% 할인
#
# 입력된 제목: A국문U재6단 Nh戩 緎茓)h인 이踲진 추모 灋4
# 복원된 제목: 한국문화재재단 12일 장구 명인 이성진 추모 공연
#
#
# --------------------------------------------
# 결과 : 기|미술관52S기당!?만4}* 사람hIU]F -- 국립현대미술품관 2024년 4월 6일 특별전 개막
# --------------------------------------------
# Processed 1571/1602 rows - Time taken: 17.71 seconds.
#
# 예시:
# 입력된 제목: 20대 여성 V7서 실^…전叻Mc성 살해毽피kfv연|漗N?'종-
# 복원된 제목: 20대 여성 전주서 실종…전주 여성 살해 피의자 연관 가능성종합
#
# 입력된 제목: 3!16동 현장 ,금은(독립운동유k지 위o영t 공개
# 복원된 제목: 3·1운동 현장 지금은…독립운동유적지 위성영상 공개
#
# 입력된 제목: 주X키(\문화원nF원庯p`; 행CL개최
# 복원된 제목: 주터키한국문화원 개원 8주년 행사 개최
#
#
# --------------------------------------------
# 결과 : 軍v<들 전용3량 타고 골l장y…`덕적 해R 심각 -- 군용 헬기 전용 착륙장 시설 점검...덕적으로 인한 해양 사고 심각종합 1
# --------------------------------------------
# Processed 1572/1602 rows - Time taken: 17.74 seconds.
#
# 예시:
# 입력된 제목: 새누리)T 원9S'에 정진석…]N위의" `f림속(
# 복원된 제목: 새누리 새 원내대표에 정진석…정책위의장 김광림속보
#
# 입력된 제목: 4$) 대표 취임 축.\난 앞에 +고 L}말
# 복원된 제목: 이해찬 대표 취임 축하 난 앞에 놓고 인사말
#
# 입력된 제목: 장S인 t책 발`하_ k竅수
# 복원된 제목: 장애인 정책 발표하는 안철수
#
#
# --------------------------------------------
# 결과 : 단군·동whF 1hj다Wf 핵실7 정[화 억9 -- 한국 단군 신화 관련 핵시설 안전 점검 착수
# --------------------------------------------
# Processed 1573/1602 rows - Time taken: 16.04 seconds.
#
# 예시:
# 입력된 제목: MBC!류현진:특5 V7mMLkBD설B게wDb 류현Z
# 복원된 제목: MBC 류현진 특집 다큐…MLB 전설에게 듣는 류현진
#
# 입력된 제목: 프로농구XAr ③ N인'e r-d·양旎S의 30g스詈…s(Y
# 복원된 제목: 프로농구 개막 ③ 헤인즈의 1만점·양동근의 900스틸…...
#
# 입력된 제목: 되살아~ 捛라饂6"拶尺 sW에 Oy#판정에 K4
# 복원된 제목: 되살아난 트라우마 롯데 연패에 울고 판정에 울고
#
#
# --------------------------------------------
# 결과 : 쿠Xi·코스w·뎀s레N=R하는R축D스타들R나@이적시켜3 -- 쿠XI 코스웨어...패션 디자이너들이 선택한 스타일 브랜드들의 인기
# --------------------------------------------
# Processed 1574/1602 rows - Time taken: 20.14 seconds.
#
# 예시:
# 입력된 제목: 미f/무역k상xs안에琐코스피 骘斘{2150rJ穎~종P
# 복원된 제목: 미중 무역협상 불안에 코스피 장중 2150대 후퇴종합
#
# 입력된 제목: 지난x 수도# 5M트 U균U&i가I=억3천만원
# 복원된 제목: 지난해 수도권 아파트 평균 거래가 3억3천만원
#
# 입력된 제목: 성o憺,OD에 증d가 r간 \장률 전망치 裵vL2浻h%b 하향
# 복원된 제목: 성장률 쇼크에 증권가 연간 성장률 전망치 2.22.3%로 하향
#
#
# --------------------------------------------
# 결과 : 우리은B DgK아 u회j|2O 합병U현지O5B 저축XR -- 우리은행, 아시아나 항공 합병 후 현지 법인 100% 자회사로 전환저축
# --------------------------------------------
# Processed 1575/1602 rows - Time taken: 18.55 seconds.
#
# 예시:
# 입력된 제목: kz 4·3 아픔 J듬p4시!…伣]? k=d다녀禞 이름들
# 복원된 제목: 제주 4·3 아픔 보듬는 시집…꽃보다 먼저 다녀간 이름들
#
# 입력된 제목: b7V냄새C#나B데)5근길 마=tM수상LX@ 따%Ss"니
# 복원된 제목: 영상 냄새가 나는데…퇴근길 마주친 수상한 차 따라가봤더니
#
# 입력된 제목: 국sPr박w- &8트u6라 등%8n볼qU계문y관 개관
# 복원된 제목: 국립중앙박물관 이집트 미라 등 만나볼 세계문화관 개관
#
#
# --------------------------------------------
# 결과 : 진: x백숲P걷기)2w힐링8스"r가꾼e -- 진해 숲속 걷기 여행...2박 3일 힐링 여행 준비가꾸네
# --------------------------------------------
# Processed 1576/1602 rows - Time taken: 18.12 seconds.
#
# 예시:
# 입력된 제목: 1의종군 최a환)경{H{\서.족쇄 O2=笓소釪
# 복원된 제목: 백의종군 최경환 경북 모임서 족쇄 풀렸다 소회
#
# 입력된 제목: 伊0姰k jV 3171 =축q錪(鐍 `발…L*재v5에N청^
# 복원된 제목: 伊의원들 의석 3분의1 감축 법안에 반발…헌법재판소에 청원
#
# 입력된 제목: 출근하6 통일M 장관
# 복원된 제목: 출근하는 통일부 장관
#
#
# --------------------------------------------
# 결과 : 북한도|Y르스}:료…개s공단 출:p원m발열W사RXj종합 -- 북한도 러시아와 협력 관계 발전 기대...개성공단 출자회사 발열사 RX종합발전소
# --------------------------------------------
# Processed 1577/1602 rows - Time taken: 17.82 seconds.
#
# 예시:
# 입력된 제목: (성y권}LG전Rl暐장g방향성:재x=…목표c↑
# 복원된 제목: 삼성증권 LG전자 성장 방향성 재평가…목표가↑
#
# 입력된 제목: 鏊성A도 )해 ( !;…7N/D'2c 4/,99억毎 규]Z합
# 복원된 제목: 삼성重도 올해 첫 수주…LNG선 2척 4천199억원 규모종합
#
# 입력된 제목: 특/, 2기사<*타FUT지분 g입에~K?칼 약세
# 복원된 제목: 특징주 백기사 델타항공 지분 매입에 한진칼 약세
#
#
# --------------------------------------------
# 결과 : 여[어:B안M예약H3Q중복예약!B^B62% x소 -- 여자 월드컵 예약 시스템 오류! 60% 중복 예약 문제 발생
# --------------------------------------------
# Processed 1578/1602 rows - Time taken: 18.34 seconds.
#
# 예시:
# 입력된 제목: E트넘 포체V노1麶y 컵&대회,로\8g !침 유C F5
# 복원된 제목: 토트넘 포체티노 감독 컵 대회 로테이션 방침 유지 시사
#
# 입력된 제목: S로야구挝LG 29일부/ X$耵e치徻마무리hiJ
# 복원된 제목: 프로야구 LG 29일부터 일본 고치 마무리 훈련
#
# 입력된 제목: 膨레 컨페:컵22Q>A서0L은 T일과 坨1 州:부
# 복원된 제목: 칠레 컨페드컵 2차전에서 젊은 독일과 11 무승부
#
#
# --------------------------------------------
# 결과 : 3>P영웅m박항서x 금Iz향…Oe명:xXK>에 카:레e드 -- 베트남 영웅 박항서도 아세안컵에서 금메달 획득
# --------------------------------------------
# Processed 1579/1602 rows - Time taken: 18.28 seconds.
#
# 예시:
# 입력된 제목: >한미沾)鄯관P&縅>는帋?-:}d
# 복원된 제목: 주한미군사령관 경례받는 문 대통령
#
# 입력된 제목: 朴V瞔령}13일BE핵d담화·회|…경제(안!:리? 호+
# 복원된 제목: 朴대통령 13일 북핵 담화·회견…경제법안 처리도 호소
#
# 입력된 제목: 김bH법 합5f더~60다?스러운 일V)명사회d노력 jd
# 복원된 제목: 김영란법 합헌 더민주 다행스러운 일…투명사회 노력 계속
#
#
# --------------------------------------------
# 결과 : sh기하는 이p미w대표와 >i하)/QQ표 -- 시진핑 중국 대표와 회담하며
# --------------------------------------------
# Processed 1580/1602 rows - Time taken: 17.75 seconds.
#
# 예시:
# 입력된 제목: v상 O~진W내가5홈런zk1P 팀J대_xYLE중요한...
# 복원된 제목: 영상 류현진 내가 홈런 친 후 팀 대량 득점 중요한...
#
# 입력된 제목: GC칼텍E 러츠 xz리아k서 筮叞때보다 鞮미있어:
# 복원된 제목: GS칼텍스 러츠 이탈리아에서 뛸 때보다 재미있어요
#
# 입력된 제목: vwg4AgbU3노 Qck^리 오승환D p다
# 복원된 제목: MLB닷컴 오타비노 떠난 자리 오승환이 있다
#
#
# --------------------------------------------
# 결과 : 12월)ko% 손흥H =?u시즌보D T른jEu 가속도 -- 손준호 내년 시즌 보는 것이 기대돼요
# --------------------------------------------
# Processed 1581/1602 rows - Time taken: 17.04 seconds.
#
# 예시:
# 입력된 제목: '바논서 사!皡w거리시y…경9난에 x5"진 요1
# 복원된 제목: 레바논서 사흘째 거리시위…경제난에 정권퇴진 요구
#
# 입력된 제목: "탈리아프+스 정상TE息 v민>자동 Pc 시스7 w입 %의
# 복원된 제목: 이탈리아프랑스 정상 EU 난민 자동 배분 시스템 도입 합의
#
# 입력된 제목: E부가D3飍V 바6蒮.수단G전A6통5 교도소T수감
# 복원된 제목: 군부가 축출한 바시르 수단 전 대통령 교도소 수감
#
#
# --------------------------------------------
# 결과 : 美|Tb3{주+대서(K격…8명 부상…1명{중N1보 -- 미국서 대규모 시위...경찰 진압으로 8 명 부상, 1 명 중상
# --------------------------------------------
# Processed 1582/1602 rows - Time taken: 18.00 seconds.
#
# 예시:
# 입력된 제목: 3G0만[인구에r의대 정酏j겨우$76명…GCZkFz인력|확Y하라
# 복원된 제목: 340만 인구에 의대 정원 겨우 76명…경남 의료 인력 확충하라
#
# 입력된 제목: z산2부e일센터D직업9)4n B%w^여2 1p. 취업 지.
# 복원된 제목: 울산중부새일센터 직업교육으로 경력단절여성 19명 취업 지원
#
# 입력된 제목: 한(5송협s장에 박정p]g輯i8사장G6\
# 복원된 제목: 한국방송협회장에 박정훈 SBS 사장 취임
#
#
# --------------------------------------------
# 결과 : $G ;!p 서울 |곳 나vo객 =적"bs 귀s,d거) -- 서울 도심 버스 정류장에 CCTV 설치해 교통 사고 예방
# --------------------------------------------
# Processed 1583/1602 rows - Time taken: 19.79 seconds.
#
# 예시:
# 입력된 제목: 롯$그3$글로Xe진-J3禨x7뀐다
# 복원된 제목: 롯데그룹 글로벌 진출 지도 바뀐다
#
# 입력된 제목: 게시S '!暡협금융 =8장 '영협_ _결
# 복원된 제목: 게시판 NH농협금융 부문장 경영협약 체결
#
# 입력된 제목: p대중bfsq천E달러g)H 산p鉏Z로A f량卆[4
# 복원된 제목: 현대중공업 4천만달러 규모 산업용 로봇 대량 수주
#
#
# --------------------------------------------
# 결과 :  Q산U 림자금\ I,SC다…Y감원장 b합YM시스템_구6 -- 금융위원회 감독원장 시스템 구축 합의
# --------------------------------------------
# Processed 1584/1602 rows - Time taken: 16.59 seconds.
#
# 예시:
# 입력된 제목: w북3장마Y선?P향…내일FK q[\{Pf㎜x비
# 복원된 제목: 충북 장마전선 영향…내일까지 50∼100㎜ 비
#
# 입력된 제목: n산국제코미~.8<벌에 참鎲합u6
# 복원된 제목: 부산국제코미디페스티벌에 참여합니다
#
# 입력된 제목: o천 OB= [?야z脸q0국F송n상"작품상涠^상
# 복원된 제목: 춘천 MBC 나이야가라 한국방송대상 작품상 수상
#
#
# --------------------------------------------
# 결과 : 청Z한 1요BM전국 vvX큰>일d>T감fcN*M세요 -- 청년층 전국 규모 취업 박람회 큰 호응...일자리 창출 기대
# --------------------------------------------
# Processed 1585/1602 rows - Time taken: 17.04 seconds.
#
# 예시:
# 입력된 제목: n 3躼년만의^)兦k0'w(김J은 우상화…주민{V2커져>합
# 복원된 제목: 北 36년만의 당대회 맞아 김정은 우상화…주민불만 커져종합
#
# 입력된 제목: [u~하는4h준표와 戶성@
# 복원된 제목: 이야기하는 홍준표와 김성태
#
# 입력된 제목: 올c5.펜스와 UM 뒤로 김嬚-과N김%정
# 복원된 제목: 올림픽 펜스와 아베 뒤로 김영남과 김여정
#
#
# --------------------------------------------
# 결과 : M용표F北2태영tzbZ자 취@은 체제영향 줄t~는 것 -- 美 용표 北 태영호 대사 망명 체제 영향 줄 것이라는
# --------------------------------------------
# Processed 1586/1602 rows - Time taken: 17.43 seconds.
#
# 예시:
# 입력된 제목: 성장률_Kg에 UA가 6간m성장:(전"qE8*2-.)%;z하.
# 복원된 제목: 성장률 쇼크에 증권가 연간 성장률 전망치 2.22.3%로 하향
#
# 입력된 제목: k럼파스}`21억원pT 자wL 시간외閧@Y 5정
# 복원된 제목: 프럼파스트 21억원어치 자사주 시간외 매매 결정
#
# 입력된 제목: 국O채 {e Z7o;]"g-(M 연 1D7*垕%
# 복원된 제목: 국고채 금리 일제히 하락…3년물 연 1.717%
#
#
# --------------------------------------------
# 결과 : 원달러v환율 *락해"1220]선 아O-j경기부양 4$감 -- 원달러 환율 30일만에 9원 하락해 8원 선...경기
# --------------------------------------------
# Processed 1587/1602 rows - Time taken: 19.87 seconds.
#
# 예시:
# 입력된 제목: v!준 K9u,T喵I嬊인공지N 종합j-소; n9W8다
# 복원된 제목: 김명준 원장 ETRI 인공지능 종합연구소로 거듭나겠다
#
# 입력된 제목: `생K 생_O(전k5단侶질 W ~ 버口u *\다
# 복원된 제목: 항생제 생산 유전자 단백질 될 때 버퍼링 걸린다
#
# 입력된 제목: ZKS_}^NIL드림팀 완성…4WI리서V센BY조>#~설
# 복원된 제목: SK텔레콤 AI 드림팀 완성… AI리서치센터 조직 신설
#
#
# --------------------------------------------
# 결과 : *@이RAO _zW첫 스3#U 메\트,20…최고 1L(Y원OV출} -- 이수영 연구원 첫 연구 프로젝트 발표, 최고의 성과 기대
# --------------------------------------------
# Processed 1588/1602 rows - Time taken: 17.82 seconds.
#
# 예시:
# 입력된 제목: 보HX釗 m령시 시EXJUg공$원 F명 모집
# 복원된 제목: 보령소식 보령시 시간선택제 공무원 3명 모집
#
# 입력된 제목: x}령#휴양j 저I-n입@한…정비6|罾년 }월X재개방B_
# 복원된 제목: 대통령 휴양지 저도 출입제한…정비후 내년 3월 재개방종합
#
# 입력된 제목: 우3敏행~디지v전환 가\e…j5]발굴SO25 추진
# 복원된 제목: 우리은행 디지털전환 가속화…과제 발굴해 적극 추진
#
#
# --------------------------------------------
# 결과 : 문답으0`#어=mX거*지T로드맵 n\내#]C -- 문대통령 경제로드map 발표...내달 26일 4대그룹 CEOs 회동
# --------------------------------------------
# Processed 1589/1602 rows - Time taken: 18.09 seconds.
#
# 예시:
# 입력된 제목: 페_스u X#j4體t濣r凳d9I킹!,KR…"시기,9榏이익
# 복원된 제목: 페이스북 읽는 시간 뉴스피드 랭킹에 반영…낚시기사 불이익
#
# 입력된 제목: 7.c16\4Vj과총U창립o50)旝T기념C麓
# 복원된 제목: 7월 1314일 과총 창립 50주년 기념사업
#
# 입력된 제목: d년 r지mG일sz s 3차&추* 사;@민간=채t률:겨우>11}
# 복원된 제목: 청년 디지털 일자리 등 3차 추경 사업 민간 채용률 겨우 11%
#
#
# --------------------------------------------
# 결과 : PD호Gx동y와5서면합의로\ %]t}제 u정안 발의 -- 대통령 개헌안 국회 서면 합의로 의결 추진
# --------------------------------------------
# Processed 1590/1602 rows - Time taken: 20.54 seconds.
#
# 예시:
# 입력된 제목: & p}리미S일l기습발사u_능성U발사C에 가림막G설치
# 복원된 제목: 北 장거리미사일 기습발사 가능성…발사대에 가림막 설치
#
# 입력된 제목: & 무수단 OI 汗기vM^z입9기T L보 P(가B관&
# 복원된 제목: 北 무수단 발사 대기권 재진입 기술 확보 여부가 관건
#
# 입력된 제목: 7瑥U·삿]질·/성H몸(움…P장 치!.ebU미tv
# 복원된 제목: 폭로전·삿대질·고성·몸싸움…막장 치닫는 바른미래당
#
#
# --------------------------------------------
# 결과 : 송희경  j호i7Q출장 시yQ등2 아_1비즈M스c]|용(d -- 송희숙 의원, 출장 시 비공식 업무 수행 논란..."비공식 비즈니스" 용
# --------------------------------------------
# Processed 1591/1602 rows - Time taken: 20.12 seconds.
#
# 예시:
# 입력된 제목: 骫G=자{먼Nn입l"레질b)선 청镈기x출1
# 복원된 제목: LG전자 먼지흡입물걸레질 무선 청소기 출시
#
# 입력된 제목: 인捭% BxyB 개발한 자3주'차
# 복원된 제목: 인텔이 BMW와 개발한 자율주행차
#
# 입력된 제목: @0f9니%M판O38분 ba\|감…접속cP려 에z+k)
# 복원된 제목: 카카오미니 예판 38분 만에 마감…접속 몰려 에러 속출
#
#
# --------------------------------------------
# 결과 : +클리 스마트G=<MVx 쓸Y때c가장{jZf까 -- 클리앙 스마트 TV 쓸 때 가장 자주 문제 발생하는 상황
# --------------------------------------------
# Processed 1592/1602 rows - Time taken: 16.88 seconds.
#
# 예시:
# 입력된 제목: 0d기하는 ?준K} n성Y
# 복원된 제목: 이야기하는 홍준표와 김성태
#
# 입력된 제목: )교안·나경-`y스트:랙0Qi 경찰k출석통보`e2S 입장
# 복원된 제목: 황교안·나경원 패스트트랙 사건 경찰 출석통보에 불응 입장
#
# 입력된 제목: 熾주*$리縂정예산rx보^대8=법인P\u刱 모색
# 복원된 제목: 민주 누리과정예산 확보 대신 법인세 양보 모색
#
#
# --------------------------------------------
# 결과 : 北0대! 김정*2향한 "성경쟁 무대된l릴레이r토론 -- 북한 핵문제 둘러싼 경쟁 무대 된 릴레이 토론
# --------------------------------------------
# Processed 1593/1602 rows - Time taken: 16.81 seconds.
#
# 예시:
# 입력된 제목: 구:"鍴써보Qrl똑lV 한K|E상 필簀wy2비KA 부躵
# 복원된 제목: 구글홈 써보니 똑똑하긴 한데…막상 필요한 서비스는 부족
#
# 입력된 제목: 삼성 <H트9 미국 컨슈1DW트 黈마*폰 평G'p1~
# 복원된 제목: 삼성 갤노트9 미국 컨슈머리포트 스마트폰 평가서 1위
#
# 입력된 제목: S鎑T 부산(,N포서 g양J轇g통N@술 시堜
# 복원된 제목: SKT 부산 엑스포서 해양안전 통신기술 시연
#
#
# --------------------------------------------
# 결과 : 화합물 몸 안에서 짝F 단백질 m는 법 새로Q개U -- 단백질과 화합물이 몸에서 어떻게 상호작용하는지 새로운 방법으로 규명
# --------------------------------------------
# Processed 1594/1602 rows - Time taken: 17.45 seconds.
#
# 예시:
# 입력된 제목: 椵 한 揥 내P자…,@,구}Z표팀 k탱it'{H/의>힘
# 복원된 제목: 일 한 번 내보자…여자축구 대표팀 지탱하는 베테랑의 힘
#
# 입력된 제목: 4紝$ 도로공V 감j!힘에 ,쳤EZ2차전Aa'된俬
# 복원된 제목: 김종민 도로공사 감독 힘에 부쳤다…2차전 걱정된다
#
# 입력된 제목: 울산%대{K아디다QDhl그 ]A부滸p~리> X] ~속 우v
# 복원된 제목: 울산현대고 아디다스 K리그 고등부 축구리그 4년 연속 우승
#
#
# --------------------------------------------
# 결과 : Z현진의>. 다7Y무{R빠른 템포/팀 성적까지 영C -- 현진의 빠른 템포가 팀 성적 향상에 기여
# --------------------------------------------
# Processed 1595/1602 rows - Time taken: 19.87 seconds.
#
# 예시:
# 입력된 제목: 완벽 ,비掝두獾 롯데]완汎B고<60승E|지[선舆
# 복원된 제목: 완벽 수비 두산 롯데 완파하고 60승 고지 선착
#
# 입력된 제목: l시窵Hn^라오스 #구O滲리랑(에l패배…짧簲CcZ%한`.l
# 복원된 제목: 아시안게임 라오스 야구 스리랑카에 패배…짧지만 강렬한...
#
# 입력된 제목: u웨덴 ,4OTI표* 1니폼 문구로%여1ijz.페9
# 복원된 제목: 스웨덴 여자축구대표팀 유니폼 문구로 여성인권 캠페인
#
#
# --------------------------------------------
# 결과 : 고려·vq 5|째 결승 격돌la~일,%3대o농구 챔피Tw -- 고려대 농구팀 3학년과 4학년 결승 대결
# --------------------------------------------
# Processed 1596/1602 rows - Time taken: 20.84 seconds.
#
# 예시:
# 입력된 제목: 경Q교육청q기q위l 시Xw환경교a 강葷 비상 bA
# 복원된 제목: 경남교육청 기후위기 시대 환경교육 강화 비상 선언
#
# 입력된 제목: 우리은U _+털{환 가속j…~제 汻U偯 적극 ]符
# 복원된 제목: 우리은행 디지털전환 가속화…과제 발굴해 적극 추진
#
# 입력된 제목: 게~판CYBC B입사< 공개8용
# 복원된 제목: 게시판 MBC 신입사원 공개채용
#
#
# --------------------------------------------
# 결과 : 텅 빈 }실 선생님+홀K Y|q% T+X C1 -- 텅 빈 교실 선생 떠난 학교의 현실
# --------------------------------------------
# Processed 1597/1602 rows - Time taken: 18.54 seconds.
#
# 예시:
# 입력된 제목: f란 美 드^%t%> 침Y 8인할/수 없hh증거 있憠
# 복원된 제목: 이란 美 드론의 영공 침범 부인할 수 없는 증거 있어
#
# 입력된 제목: h선Mj 哽둔 x이든의 e쁜손MuB跜>o> 1!려凿 .8
# 복원된 제목: 대선출마 앞둔 바이든의 나쁜손 또 폭로…코 비비려고 했다
#
# 입력된 제목: ,Z위7인니 대:령y휴:전화 없bC쓰Q도y않는h
# 복원된 제목: 조코위 인니 대통령 휴대전화 없고 쓰지도 않는다
#
#
# --------------------------------------------
# 결과 : 13이 노바 라이n2·미J어패0 T3 10 결G상품% * -- 1. 3인조 살인범 검거, 범인들은 전직 군인들
# --------------------------------------------
# Processed 1598/1602 rows - Time taken: 23.58 seconds.
#
# 예시:
# 입력된 제목: 영상\`새가 나는;…L근길,마주친 수o)ID 따q3h더니
# 복원된 제목: 영상 냄새가 나는데…퇴근길 마주친 수상한 차 따라가봤더니
#
# 입력된 제목: U@올림픽_[g부2강원도Pb국S O광( W0h!_羧유치
# 복원된 제목: 관광올림픽에 승부…강원도 외국인 관광객 300만명 유치
#
# 입력된 제목: 다음달=4FmR 4 &$전& E6i어 열-다
# 복원된 제목: 다음달 4∼7일 첫 민화전문 아트페어 열린다
#
#
# --------------------------------------------
# 결과 : 남원소식 춘>X학%단+장Rn 모집 -- 남원 소식: 봄 학기 대학생 모집 안내
# --------------------------------------------
# Processed 1599/1602 rows - Time taken: 21.10 seconds.
#
# 예시:
# 입력된 제목: 朴m통령 시릴만큼7아]게 부모잃어o안보소명론@로 사Y호소종합
# 복원된 제목: 朴대통령 시릴만큼 아프게 부모잃어…안보소명론으로 사드호소종합
#
# 입력된 제목: RN통?Q한Z岎기H인에*'동\YE]G
# 복원된 제목: 朴대통령 한러 기업인에 극동협력 당부
#
# 입력된 제목: 北Q유^제재로?수Sq힌塼B|L발X에d사蔀…b력5 d嫜
# 복원된 제목: 北 유엔제재로 수출막힌 석탄 발전에 사용…전력난 완화
#
#
# --------------------------------------------
# 결과 : 이총리,세4. H직 완fl지 못해E할 일 꽤;남아 -- 이낙연 총리, 4대 사회보험제도 완납 못해...남은 과제 많아
# --------------------------------------------
# Processed 1600/1602 rows - Time taken: 22.14 seconds.
# Checkpoint saved at row 1600.
#
# 예시:
# 입력된 제목: 벤.* &R안1CCHM\종蹈 GIHt국 UAH에 h착
# 복원된 제목: 벤투호 아시안컵 C조 최종전 상대 중국 UAE에 도착
#
# 입력된 제목: n~만 2sf`[속 r_…O율~jn26T
# 복원된 제목: 최지만 2경기 연속 안타…타율 0.269
#
# 입력된 제목: 울산 안방서3상하이 상Wa%덜미잡m.A煠C]챔스리그 +o패
# 복원된 제목: 울산 안방서 상하이 상강에 덜미잡혀 AFC 챔스리그 첫 패
#
#
# --------------------------------------------
# 결과 : 높`X#E율…}BO Q"[/선수 몸값 상승 CAO -- 손흥민 선수 몸값 상승세 지속...유럽 내 최고 수준 도달
# --------------------------------------------
# Processed 1601/1602 rows - Time taken: 24.01 seconds.
#
# 예시:
# 입력된 제목: a-트8蒇중)Y B2`g출시…모\일!제o제휴M&"
# 복원된 제목: 갤노트8 중국서 29일 출시…모바일결제 제휴 확대
#
# 입력된 제목: Sb麤芁y래 抻b 잡는다
# 복원된 제목: SKT 미래 고객 잡는다
#
# 입력된 제목: 한殱 달>탐*F등 D}s] Nf 받;다C합
# 복원된 제목: 한국 달 탐사 등 우주개발 탄력 받는다종합
#
#
# --------------------------------------------
# 결과 : 텔레그램+한D 등h亞서 2시간H다운…C버T정gf39종!2보 -- 텔레그램 한달 무료 이용 등 아시아서 서비스 30분 단축...버전
# --------------------------------------------
# Processed 1602/1602 rows - Time taken: 18.65 seconds.
# Final denoised results saved.
